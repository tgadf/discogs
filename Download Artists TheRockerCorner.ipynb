# %% [markdown]
# # The Rocker Corner

# %%
######################################################
# Juypter
######################################################
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))


######################################################
# General
######################################################
from ioUtils import saveJoblib, loadJoblib, saveFile, getFile
import urllib
from urllib.parse import quote
from collection import collections
from artist import artist
from timeUtils import clock, elapsed
from fsUtils import moveFile, setFile, setDir, setSubDir, isFile, isDir, mkDir
from ioUtils import getFile, saveFile
from fileUtils import getFileBasics, getBasename
from webUtils import getWebData, getHTML, getURL
from time import sleep
import time
from multiprocessing import Pool


######################################################
# Music Stuff
######################################################
from discogsBase import discogs
from artistRC import artistRC
from artistsRC import artistsRC
from discogsUtils import rockcornerUtils
from multiArtist import multiartist
from myMusicDBMap import myMusicDBMap


######################################################
# Versions
######################################################
import sys
print("Python: {0}".format(sys.version))
import datetime as dt
start = dt.datetime.now()
print("Notebook Last Run Initiated: "+str(start))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# Python: 3.7.3 (default, Mar 27 2019, 16:54:48)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# Notebook Last Run Initiated: 2020-04-02 18:43:44.107277

# %% [markdown]
# # Initialize

# %%
# %load_ext autoreload
# %autoreload
discRC = discogs('rockcorner')
dutils = rockcornerUtils()
artRC  = artistRC()
artsRC = artistsRC(discRC)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Music DB

# %%
mdb = myMusicDBMap(debug=True)
# Out:
# Creating myMusicDBMap()
# /Users/tgadfort/Documents/code/discogs
#    Loading my music db map: /anaconda3/envs/py37/musicdb/myMusicMap.p
#    DB keys: ['Discogs', 'AllMusic', 'MusicBrainz', 'AceBootlegs', 'RateYourMusic', 'LastFM', 'DatPiff', 'RockCorner']
# Counter({'Discogs': 3851, 'AllMusic': 3760, 'MusicBrainz': 3622, 'LastFM': 1480, 'AceBootlegs': 80, 'DatPiff': 56, 'RateYourMusic': 22, 'RockCorner': 3})

# %% [markdown]
# # Test

# %%
url="https://www.therockcorner.com/alannah-myles/"
savename="trc.p"
from webUtils import getWebData
getWebData(base=url, savename=savename, useSafari=False)

# %%
bsdata = getHTML("trc.p")

# %% [markdown]
# # Search

# %%
artsRC.searchRockCornerForArtist("Alannah Myles")
# Out:
# ===================== Searching For Alannah Myles =====================
# Found 4 artists
# 1 / 4 	: 341093961 	 https://www.therockcorner.com/alannah-myles
# Saving /Users/tgadfort/Music/Discog/artists-rockcorner/61/341093961.p (force=False)
#   --> This file is 13.8kB.
# Done. Sleeping for 2 seconds
# 2 / 4 	: 307006520 	 https://www.therockcorner.com/sevendust
# Saving /Users/tgadfort/Music/Discog/artists-rockcorner/20/307006520.p (force=False)
#   --> This file is 14.4kB.
# Done. Sleeping for 2 seconds
# 3 / 4 	: 718959345 	 https://www.therockcorner.com/disturbed
# Saving /Users/tgadfort/Music/Discog/artists-rockcorner/45/718959345.p (force=False)
#   --> This file is 13.9kB.
# Done. Sleeping for 2 seconds
# 4 / 4 	: 379499196 	 https://www.therockcorner.com/slash
# Saving /Users/tgadfort/Music/Discog/artists-rockcorner/96/379499196.p (force=False)
#   --> This file is 14.4kB.
# Done. Sleeping for 2 seconds

# %% [markdown]
# # Download All Music

# %%
def downloadRockerCornerArtists(minI=-1):
    artists = mdb.getArtists()
    for i,artistName in enumerate(artists):
        if i <= minI:
            continue
        print("====>",i,"/",len(artists),"  : ",artistName)
        artsRC.searchRockCornerForArtist(artistName, sleeptime=30)
        sleep(30)

# %%
downloadRockerCornerArtists(27)
# Out:
# ====> 28 / 3942   :  Ancient
#
#
# ===================== Searching For Ancient =====================
# Found 30 artists
# 1 / 30 	: 80032968 	 https://www.therockcorner.com/amon-amarth
# Saving /Volumes/Biggy/Discog/artists-rockcorner/68/80032968.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 30 seconds
# 2 / 30 	: 812425269 	 https://www.therockcorner.com/yes
# Saving /Volumes/Biggy/Discog/artists-rockcorner/69/812425269.p (force=False)
#   --> This file is 17.1kB.
# Done. Sleeping for 30 seconds
# 3 / 30 	: 631771879 	 https://www.therockcorner.com/tiamat
# 4 / 30 	: 773132441 	 https://www.therockcorner.com/johnny-cash
# 5 / 30 	: 850154934 	 https://www.therockcorner.com/wishbone-ash
# Saving /Volumes/Biggy/Discog/artists-rockcorner/34/850154934.p (force=False)
#   --> This file is 15.3kB.
# Done. Sleeping for 30 seconds
# 6 / 30 	: 64936935 	 https://www.therockcorner.com/the-cribs
# Saving /Volumes/Biggy/Discog/artists-rockcorner/35/64936935.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 30 seconds
# 7 / 30 	: 18066148 	 https://www.therockcorner.com/van-morrison
# 8 / 30 	: 795620599 	 https://www.therockcorner.com/travis
# Saving /Volumes/Biggy/Discog/artists-rockcorner/99/795620599.p (force=False)
#   --> This file is 14.3kB.
# Done. Sleeping for 30 seconds
# 9 / 30 	: 654249132 	 https://www.therockcorner.com/iron-maiden
# 10 / 30 	: 173505339 	 https://www.therockcorner.com/six-feet-under
# Saving /Volumes/Biggy/Discog/artists-rockcorner/39/173505339.p (force=False)
#   --> This file is 15.0kB.
# Done. Sleeping for 30 seconds
# 11 / 30 	: 402279133 	 https://www.therockcorner.com/paul-mc-cartney
# Saving /Volumes/Biggy/Discog/artists-rockcorner/33/402279133.p (force=False)
#   --> This file is 15.4kB.
# Done. Sleeping for 30 seconds
# 12 / 30 	: 6907961 	 https://www.therockcorner.com/red-krayola
# Saving /Volumes/Biggy/Discog/artists-rockcorner/61/6907961.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 30 seconds
# 13 / 30 	: 347482497 	 https://www.therockcorner.com/dr-dog
# Saving /Volumes/Biggy/Discog/artists-rockcorner/97/347482497.p (force=False)
#   --> This file is 14.3kB.
# Done. Sleeping for 30 seconds
# 14 / 30 	: 864317668 	 https://www.therockcorner.com/the-sweet
# 15 / 30 	: 794796542 	 https://www.therockcorner.com/passion
# Saving /Volumes/Biggy/Discog/artists-rockcorner/42/794796542.p (force=False)
#   --> This file is 14.0kB.
# Done. Sleeping for 30 seconds
# 16 / 30 	: 886743452 	 https://www.therockcorner.com/built-to-spill
# Saving /Volumes/Biggy/Discog/artists-rockcorner/52/886743452.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 30 seconds
# 17 / 30 	: 442776817 	 https://www.therockcorner.com/kreator
# Saving /Volumes/Biggy/Discog/artists-rockcorner/17/442776817.p (force=False)
#   --> This file is 15.2kB.
# Done. Sleeping for 30 seconds
# 18 / 30 	: 863148830 	 https://www.therockcorner.com/morbid-angel
# Saving /Volumes/Biggy/Discog/artists-rockcorner/30/863148830.p (force=False)
#   --> This file is 14.7kB.
# Done. Sleeping for 30 seconds
# 19 / 30 	: 994660766 	 https://www.therockcorner.com/hawk-nelson
# Saving /Volumes/Biggy/Discog/artists-rockcorner/66/994660766.p (force=False)
#   --> This file is 15.0kB.
# Done. Sleeping for 30 seconds
# 20 / 30 	: 450912329 	 https://www.therockcorner.com/frank-zappa
# 21 / 30 	: 416070871 	 https://www.therockcorner.com/marcy-playground
# Saving /Volumes/Biggy/Discog/artists-rockcorner/71/416070871.p (force=False)
#   --> This file is 14.7kB.
# Done. Sleeping for 30 seconds
# 22 / 30 	: 818975879 	 https://www.therockcorner.com/tangerine-dream
# 23 / 30 	: 358754310 	 https://www.therockcorner.com/theatres-des-vampires
# 24 / 30 	: 300941147 	 https://www.therockcorner.com/galneryus
# Saving /Volumes/Biggy/Discog/artists-rockcorner/47/300941147.p (force=False)
#   --> This file is 14.5kB.
# Done. Sleeping for 30 seconds
# 25 / 30 	: 918295794 	 https://www.therockcorner.com/mastodon
# Saving /Volumes/Biggy/Discog/artists-rockcorner/94/918295794.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 30 seconds
# 26 / 30 	: 92241712 	 https://www.therockcorner.com/black-sabbath
# Saving /Volumes/Biggy/Discog/artists-rockcorner/12/92241712.p (force=False)
#   --> This file is 16.2kB.
# Done. Sleeping for 30 seconds
# 27 / 30 	: 137459170 	 https://www.therockcorner.com/the-orwells
# Saving /Volumes/Biggy/Discog/artists-rockcorner/70/137459170.p (force=False)
#   --> This file is 9.1kB.
# Done. Sleeping for 30 seconds
# 28 / 30 	: 187421577 	 https://www.therockcorner.com/interpol
# Saving /Volumes/Biggy/Discog/artists-rockcorner/77/187421577.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 30 seconds
# 29 / 30 	: 314691387 	 https://www.therockcorner.com/vangelis
# Saving /Volumes/Biggy/Discog/artists-rockcorner/87/314691387.p (force=False)
#   --> This file is 17.7kB.
# Done. Sleeping for 30 seconds
# 30 / 30 	: 209393397 	 https://www.therockcorner.com/joe-satriani
# Saving /Volumes/Biggy/Discog/artists-rockcorner/97/209393397.p (force=False)
#   --> This file is 15.8kB.
# Done. Sleeping for 30 seconds
# ====> 29 / 3942   :  And Oceans
#
#
# ===================== Searching For And Oceans =====================
# Found 40 artists
# 1 / 40 	: 309723700 	 https://www.therockcorner.com/the-black-keys
# 2 / 40 	: 525347589 	 https://www.therockcorner.com/seafret
# Saving /Volumes/Biggy/Discog/artists-rockcorner/89/525347589.p (force=False)
#   --> This file is 10.1kB.
# Done. Sleeping for 30 seconds
# 3 / 40 	: 327898703 	 https://www.therockcorner.com/tokio-hotel
# Saving /Volumes/Biggy/Discog/artists-rockcorner/3/327898703.p (force=False)
#   --> This file is 14.5kB.
# Done. Sleeping for 30 seconds
# 4 / 40 	: 567347661 	 https://www.therockcorner.com/coldplay
# 5 / 40 	: 308586791 	 https://www.therockcorner.com/sonata-arctica
# Saving /Volumes/Biggy/Discog/artists-rockcorner/91/308586791.p (force=False)
#   --> This file is 15.0kB.
# Done. Sleeping for 30 seconds
# 6 / 40 	: 47899431 	 https://www.therockcorner.com/porcupine-tree
# Saving /Volumes/Biggy/Discog/artists-rockcorner/31/47899431.p (force=False)
#   --> This file is 15.8kB.
# Done. Sleeping for 30 seconds
# 7 / 40 	: 446838907 	 https://www.therockcorner.com/the-wombats
# Saving /Volumes/Biggy/Discog/artists-rockcorner/7/446838907.p (force=False)
#   --> This file is 14.8kB.
# Done. Sleeping for 30 seconds
# 8 / 40 	: 805725981 	 https://www.therockcorner.com/twin-atlantic
# Saving /Volumes/Biggy/Discog/artists-rockcorner/81/805725981.p (force=False)
#   --> This file is 11.1kB.
# Done. Sleeping for 30 seconds
# 9 / 40 	: 56500069 	 https://www.therockcorner.com/evanescence
# Saving /Volumes/Biggy/Discog/artists-rockcorner/69/56500069.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 30 seconds
# 10 / 40 	: 761649670 	 https://www.therockcorner.com/suede
# 11 / 40 	: 813588329 	 https://www.therockcorner.com/deerhunter
# Saving /Volumes/Biggy/Discog/artists-rockcorner/29/813588329.p (force=False)
#   --> This file is 14.4kB.
# Done. Sleeping for 30 seconds
# 12 / 40 	: 712147463 	 https://www.therockcorner.com/misterwives
# Saving /Volumes/Biggy/Discog/artists-rockcorner/63/712147463.p (force=False)
#   --> This file is 9.2kB.
# Done. Sleeping for 30 seconds
# 13 / 40 	: 651887290 	 https://www.therockcorner.com/echo-and-the-bunnymen
# Saving /Volumes/Biggy/Discog/artists-rockcorner/90/651887290.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 30 seconds
# 14 / 40 	: 582397650 	 https://www.therockcorner.com/screaming-trees
# Saving /Volumes/Biggy/Discog/artists-rockcorner/50/582397650.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 30 seconds
# 15 / 40 	: 523892078 	 https://www.therockcorner.com/belle-and-sebastian
# Saving /Volumes/Biggy/Discog/artists-rockcorner/78/523892078.p (force=False)
#   --> This file is 16.1kB.
# Done. Sleeping for 30 seconds
# 16 / 40 	: 152185004 	 https://www.therockcorner.com/river-becomes-ocean
# Saving /Volumes/Biggy/Discog/artists-rockcorner/4/152185004.p (force=False)
#   --> This file is 8.3kB.
# Done. Sleeping for 30 seconds
# 17 / 40 	: 101776710 	 https://www.therockcorner.com/audio-adrenaline
# Saving /Volumes/Biggy/Discog/artists-rockcorner/10/101776710.p (force=False)
#   --> This file is 15.2kB.
# Done. Sleeping for 30 seconds
# 18 / 40 	: 812425269 	 https://www.therockcorner.com/yes
# 19 / 40 	: 563096587 	 https://www.therockcorner.com/billy-ocean
# Saving /Volumes/Biggy/Discog/artists-rockcorner/87/563096587.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 30 seconds
# 20 / 40 	: 113631567 	 https://www.therockcorner.com/dance-gavin-dance
# 21 / 40 	: 603520950 	 https://www.therockcorner.com/yellowcard
# 22 / 40 	: 892718596 	 https://www.therockcorner.com/as-i-lay-dying
# Saving /Volumes/Biggy/Discog/artists-rockcorner/96/892718596.p (force=False)
#   --> This file is 14.5kB.
# Done. Sleeping for 30 seconds
# 23 / 40 	: 770152863 	 https://www.therockcorner.com/devotchka
# Saving /Volumes/Biggy/Discog/artists-rockcorner/63/770152863.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 30 seconds
# 24 / 40 	: 263593434 	 https://www.therockcorner.com/counting-crows
# Saving /Volumes/Biggy/Discog/artists-rockcorner/34/263593434.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 30 seconds
# 25 / 40 	: 158322965 	 https://www.therockcorner.com/tori-amos
# Saving /Volumes/Biggy/Discog/artists-rockcorner/65/158322965.p (force=False)
#   --> This file is 15.2kB.
# Done. Sleeping for 30 seconds
# 26 / 40 	: 509852201 	 https://www.therockcorner.com/pearl-jam
# Saving /Volumes/Biggy/Discog/artists-rockcorner/1/509852201.p (force=False)
#   --> This file is 15.0kB.
# Done. Sleeping for 30 seconds
# 27 / 40 	: 313269584 	 https://www.therockcorner.com/survivor
# Saving /Volumes/Biggy/Discog/artists-rockcorner/84/313269584.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 30 seconds
# 28 / 40 	: 681835964 	 https://www.therockcorner.com/gotye
# Saving /Volumes/Biggy/Discog/artists-rockcorner/64/681835964.p (force=False)
#   --> This file is 12.1kB.
# Done. Sleeping for 30 seconds
# 29 / 40 	: 976375738 	 https://www.therockcorner.com/elton-john
# 30 / 40 	: 355336322 	 https://www.therockcorner.com/the-smashing-pumpkins
# Saving /Volumes/Biggy/Discog/artists-rockcorner/22/355336322.p (force=False)
#   --> This file is 14.5kB.
# Done. Sleeping for 30 seconds
# 31 / 40 	: 622809590 	 https://www.therockcorner.com/puscifer
# 32 / 40 	: 180271435 	 https://www.therockcorner.com/coasts
# Saving /Volumes/Biggy/Discog/artists-rockcorner/35/180271435.p (force=False)
#   --> This file is 9.2kB.
# Done. Sleeping for 30 seconds
# 33 / 40 	: 886706505 	 https://www.therockcorner.com/gene-pitney
# Saving /Volumes/Biggy/Discog/artists-rockcorner/5/886706505.p (force=False)
#   --> This file is 17.1kB.
# Done. Sleeping for 30 seconds
# 34 / 40 	: 978523409 	 https://www.therockcorner.com/abc-band
# 35 / 40 	: 445480476 	 https://www.therockcorner.com/eric-clapton
# Saving /Volumes/Biggy/Discog/artists-rockcorner/76/445480476.p (force=False)
#   --> This file is 16.0kB.
# Done. Sleeping for 30 seconds
# 36 / 40 	: 551631211 	 https://www.therockcorner.com/buzzcocks
# Saving /Volumes/Biggy/Discog/artists-rockcorner/11/551631211.p (force=False)
#   --> This file is 14.8kB.
# Done. Sleeping for 30 seconds
# 37 / 40 	: 868777376 	 https://www.therockcorner.com/phantogram
# Saving /Volumes/Biggy/Discog/artists-rockcorner/76/868777376.p (force=False)
#   --> This file is 11.4kB.
# Done. Sleeping for 30 seconds
# 38 / 40 	: 562084804 	 https://www.therockcorner.com/b-z
# 39 / 40 	: 508362911 	 https://www.therockcorner.com/justin-sullivan
# Saving /Volumes/Biggy/Discog/artists-rockcorner/11/508362911.p (force=False)
#   --> This file is 11.8kB.
# Done. Sleeping for 30 seconds
# 40 / 40 	: 373403196 	 https://www.therockcorner.com/toad-the-wet-sprocket
# Saving /Volumes/Biggy/Discog/artists-rockcorner/96/373403196.p (force=False)
#   --> This file is 14.3kB.
# Done. Sleeping for 30 seconds
# ====> 30 / 3942   :  Andrea Marcovicci
#
#
# ===================== Searching For Andrea Marcovicci =====================
# Found 3 artists
# 1 / 3 	: 715930424 	 https://www.therockcorner.com/yo-la-tengo
# Saving /Volumes/Biggy/Discog/artists-rockcorner/24/715930424.p (force=False)
#   --> This file is 15.6kB.
# Done. Sleeping for 30 seconds
# 2 / 3 	: 849111534 	 https://www.therockcorner.com/andrea-corr
# Saving /Volumes/Biggy/Discog/artists-rockcorner/34/849111534.p (force=False)
#   --> This file is 8.1kB.
# Done. Sleeping for 30 seconds
# 3 / 3 	: 528943759 	 https://www.therockcorner.com/legiao-urbana
# ====> 31 / 3942   :  Angizia
#
#
# ===================== Searching For Angizia =====================
# Found 0 artists
# ====> 32 / 3942   :  Ani DiFranco
#
#
# ===================== Searching For Ani DiFranco =====================
# Found 0 artists
# ====> 33 / 3942   :  Anita Baker
#
#
# ===================== Searching For Anita Baker =====================
# Found 12 artists
# 1 / 12 	: 623548133 	 https://www.therockcorner.com/primus
# Saving /Volumes/Biggy/Discog/artists-rockcorner/33/623548133.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 30 seconds
# 2 / 12 	: 562884346 	 https://www.therockcorner.com/al-stewart
# Saving /Volumes/Biggy/Discog/artists-rockcorner/46/562884346.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 30 seconds
# 3 / 12 	: 665917902 	 https://www.therockcorner.com/milli-vanilli
# Saving /Volumes/Biggy/Discog/artists-rockcorner/2/665917902.p (force=False)
#   --> This file is 12.0kB.
# Done. Sleeping for 30 seconds
# 4 / 12 	: 277314631 	 https://www.therockcorner.com/the-mountain-goats
# 5 / 12 	: 275709698 	 https://www.therockcorner.com/the-human-league
# Saving /Volumes/Biggy/Discog/artists-rockcorner/98/275709698.p (force=False)
#   --> This file is 14.8kB.
# Done. Sleeping for 30 seconds
# 6 / 12 	: 158322965 	 https://www.therockcorner.com/tori-amos
# 7 / 12 	: 400610260 	 https://www.therockcorner.com/jethro-tull
# 8 / 12 	: 645618370 	 https://www.therockcorner.com/eric-church
# Saving /Volumes/Biggy/Discog/artists-rockcorner/70/645618370.p (force=False)
#   --> This file is 17.0kB.
# Done. Sleeping for 30 seconds
# 9 / 12 	: 449193832 	 https://www.therockcorner.com/death-cab-for-cutie
# 10 / 12 	: 58255776 	 https://www.therockcorner.com/sinead-o-connor
# Saving /Volumes/Biggy/Discog/artists-rockcorner/76/58255776.p (force=False)
#   --> This file is 15.5kB.
# Done. Sleeping for 30 seconds
# 11 / 12 	: 431392333 	 https://www.therockcorner.com/deicide
# Saving /Volumes/Biggy/Discog/artists-rockcorner/33/431392333.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 30 seconds
# 12 / 12 	: 448715594 	 https://www.therockcorner.com/the-beta-band
# Saving /Volumes/Biggy/Discog/artists-rockcorner/94/448715594.p (force=False)
#   --> This file is 12.8kB.
# Done. Sleeping for 30 seconds
# ====> 34 / 3942   :  Annie Lennox
#
#
# ===================== Searching For Annie Lennox =====================
# Found 24 artists
# 1 / 24 	: 613774841 	 https://www.therockcorner.com/heart
# Saving /Volumes/Biggy/Discog/artists-rockcorner/41/613774841.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 30 seconds
# 2 / 24 	: 920936116 	 https://www.therockcorner.com/el-ten-eleven
# Saving /Volumes/Biggy/Discog/artists-rockcorner/16/920936116.p (force=False)
#   --> This file is 12.0kB.
# Done. Sleeping for 30 seconds
# 3 / 24 	: 350634735 	 https://www.therockcorner.com/elvis-presley
# 4 / 24 	: 13032242 	 https://www.therockcorner.com/ry-cooder
# 5 / 24 	: 176734158 	 https://www.therockcorner.com/steppenwolf
# Saving /Volumes/Biggy/Discog/artists-rockcorner/58/176734158.p (force=False)
#   --> This file is 14.8kB.
# Done. Sleeping for 30 seconds
# 6 / 24 	: 305468007 	 https://www.therockcorner.com/tom-waits
# 7 / 24 	: 575916326 	 https://www.therockcorner.com/squeeze
# Saving /Volumes/Biggy/Discog/artists-rockcorner/26/575916326.p (force=False)
#   --> This file is 15.6kB.
# Done. Sleeping for 30 seconds
# 8 / 24 	: 978403046 	 https://www.therockcorner.com/kids-in-glass-houses
# Saving /Volumes/Biggy/Discog/artists-rockcorner/46/978403046.p (force=False)
#   --> This file is 11.6kB.
# Done. Sleeping for 30 seconds
# 9 / 24 	: 818975879 	 https://www.therockcorner.com/tangerine-dream
# 10 / 24 	: 103591349 	 https://www.therockcorner.com/prince
# Saving /Volumes/Biggy/Discog/artists-rockcorner/49/103591349.p (force=False)
#   --> This file is 15.7kB.
# Done. Sleeping for 30 seconds
# 11 / 24 	: 717710611 	 https://www.therockcorner.com/mando-diao
# Saving /Volumes/Biggy/Discog/artists-rockcorner/11/717710611.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 30 seconds
# 12 / 24 	: 905893436 	 https://www.therockcorner.com/mac-demarco
# Saving /Volumes/Biggy/Discog/artists-rockcorner/36/905893436.p (force=False)
#   --> This file is 14.3kB.
# Done. Sleeping for 30 seconds
# 13 / 24 	: 788345115 	 https://www.therockcorner.com/tim-mcgraw
# Saving /Volumes/Biggy/Discog/artists-rockcorner/15/788345115.p (force=False)
#   --> This file is 15.8kB.
# Done. Sleeping for 30 seconds
# 14 / 24 	: 812425269 	 https://www.therockcorner.com/yes
# 15 / 24 	: 886706505 	 https://www.therockcorner.com/gene-pitney
# 16 / 24 	: 2086031 	 https://www.therockcorner.com/the-wallflowers
# Saving /Volumes/Biggy/Discog/artists-rockcorner/31/2086031.p (force=False)
#   --> This file is 14.7kB.
# Done. Sleeping for 30 seconds
# 17 / 24 	: 682075242 	 https://www.therockcorner.com/los-lonely-boys
# Saving /Volumes/Biggy/Discog/artists-rockcorner/42/682075242.p (force=False)
#   --> This file is 14.8kB.
# Done. Sleeping for 30 seconds
# 18 / 24 	: 592345494 	 https://www.therockcorner.com/mat-kearney
# Saving /Volumes/Biggy/Discog/artists-rockcorner/94/592345494.p (force=False)
#   --> This file is 13.9kB.
# Done. Sleeping for 30 seconds
# 19 / 24 	: 411558049 	 https://www.therockcorner.com/joan-baez
# 20 / 24 	: 355336322 	 https://www.therockcorner.com/the-smashing-pumpkins
# 21 / 24 	: 336033386 	 https://www.therockcorner.com/red-hot-chili-peppers
# Saving /Volumes/Biggy/Discog/artists-rockcorner/86/336033386.p (force=False)
#   --> This file is 15.5kB.
# Done. Sleeping for 30 seconds
# 22 / 24 	: 736660703 	 https://www.therockcorner.com/elefant
# Saving /Volumes/Biggy/Discog/artists-rockcorner/3/736660703.p (force=False)
#   --> This file is 9.0kB.
# Done. Sleeping for 30 seconds
# 23 / 24 	: 807671243 	 https://www.therockcorner.com/pequeno-fenix
# Saving /Volumes/Biggy/Discog/artists-rockcorner/43/807671243.p (force=False)
#   --> This file is 7.8kB.
# Done. Sleeping for 30 seconds
# 24 / 24 	: 287130443 	 https://www.therockcorner.com/chuck-berry
# Saving /Volumes/Biggy/Discog/artists-rockcorner/43/287130443.p (force=False)
#   --> This file is 16.2kB.
# Done. Sleeping for 30 seconds
# ====> 35 / 3942   :  Anvil
#
#
# ===================== Searching For Anvil =====================
# Found 2 artists
# 1 / 2 	: 80032968 	 https://www.therockcorner.com/amon-amarth
# 2 / 2 	: 77159476 	 https://www.therockcorner.com/judas-priest
# ====> 36 / 3942   :  Aqua
#
#
# ===================== Searching For Aqua =====================
# Found 17 artists
# 1 / 17 	: 904358295 	 https://www.therockcorner.com/asia
# Saving /Volumes/Biggy/Discog/artists-rockcorner/95/904358295.p (force=False)
#   --> This file is 14.5kB.
# Done. Sleeping for 30 seconds
# 2 / 17 	: 539215767 	 https://www.therockcorner.com/carlos-santana
# Saving /Volumes/Biggy/Discog/artists-rockcorner/67/539215767.p (force=False)
#   --> This file is 17.6kB.
# Done. Sleeping for 30 seconds
# 3 / 17 	: 477638310 	 https://www.therockcorner.com/glenn-frey
# Saving /Volumes/Biggy/Discog/artists-rockcorner/10/477638310.p (force=False)
#   --> This file is 14.4kB.
# Done. Sleeping for 30 seconds
# 4 / 17 	: 400610260 	 https://www.therockcorner.com/jethro-tull
# 5 / 17 	: 307644523 	 https://www.therockcorner.com/the-atlantics
# Saving /Volumes/Biggy/Discog/artists-rockcorner/23/307644523.p (force=False)
#   --> This file is 14.7kB.
# Done. Sleeping for 30 seconds
# 6 / 17 	: 382100695 	 https://www.therockcorner.com/within-temptation
# Saving /Volumes/Biggy/Discog/artists-rockcorner/95/382100695.p (force=False)
#   --> This file is 15.2kB.
# Done. Sleeping for 30 seconds
# 7 / 17 	: 928116476 	 https://www.therockcorner.com/walk-the-moon
# Saving /Volumes/Biggy/Discog/artists-rockcorner/76/928116476.p (force=False)
#   --> This file is 13.2kB.
# Done. Sleeping for 30 seconds
# 8 / 17 	: 314691387 	 https://www.therockcorner.com/vangelis
# 9 / 17 	: 650178860 	 https://www.therockcorner.com/basement
# Saving /Volumes/Biggy/Discog/artists-rockcorner/60/650178860.p (force=False)
#   --> This file is 11.5kB.
# Done. Sleeping for 30 seconds
# 10 / 17 	: 157717264 	 https://www.therockcorner.com/Buckethead
# Saving /Volumes/Biggy/Discog/artists-rockcorner/64/157717264.p (force=False)
#   --> This file is 16.7kB.
# Done. Sleeping for 30 seconds
# 11 / 17 	: 562084804 	 https://www.therockcorner.com/b-z
# 12 / 17 	: 114343117 	 https://www.therockcorner.com/courtney-barnett
# Saving /Volumes/Biggy/Discog/artists-rockcorner/17/114343117.p (force=False)
#   --> This file is 9.8kB.
# Done. Sleeping for 30 seconds
# 13 / 17 	: 918295794 	 https://www.therockcorner.com/mastodon
# 14 / 17 	: 886958854 	 https://www.therockcorner.com/ian-anderson
# Saving /Volumes/Biggy/Discog/artists-rockcorner/54/886958854.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 30 seconds
# 15 / 17 	: 912953093 	 https://www.therockcorner.com/luis-alberto-spinetta
# 16 / 17 	: 889928614 	 https://www.therockcorner.com/the-flaming-lips
# Saving /Volumes/Biggy/Discog/artists-rockcorner/14/889928614.p (force=False)
#   --> This file is 17.0kB.
# Done. Sleeping for 30 seconds
# 17 / 17 	: 713560506 	 https://www.therockcorner.com/balmorhea
# Saving /Volumes/Biggy/Discog/artists-rockcorner/6/713560506.p (force=False)
#   --> This file is 14.2kB.
# Done. Sleeping for 30 seconds
# ====> 37 / 3942   :  Arctic Monkeys
#
#
# ===================== Searching For Arctic Monkeys =====================
# Found 14 artists
# 1 / 14 	: 766035238 	 https://www.therockcorner.com/arctic-monkeys
# 2 / 14 	: 682075242 	 https://www.therockcorner.com/los-lonely-boys
# 3 / 14 	: 192172830 	 https://www.therockcorner.com/iggy-pop
# Saving /Volumes/Biggy/Discog/artists-rockcorner/30/192172830.p (force=False)
#   --> This file is 15.2kB.
# Done. Sleeping for 30 seconds
# 4 / 14 	: 883300228 	 https://www.therockcorner.com/cracker
# Saving /Volumes/Biggy/Discog/artists-rockcorner/28/883300228.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 30 seconds
# 5 / 14 	: 651887290 	 https://www.therockcorner.com/echo-and-the-bunnymen
# 6 / 14 	: 401701289 	 https://www.therockcorner.com/iron-wine
# 7 / 14 	: 403529639 	 https://www.therockcorner.com/gwar
# Saving /Volumes/Biggy/Discog/artists-rockcorner/39/403529639.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 30 seconds
# 8 / 14 	: 740135410 	 https://www.therockcorner.com/ringo-starr
# 9 / 14 	: 85557324 	 https://www.therockcorner.com/spoon
# Saving /Volumes/Biggy/Discog/artists-rockcorner/24/85557324.p (force=False)
#   --> This file is 14.8kB.
# Done. Sleeping for 30 seconds
# 10 / 14 	: 707324168 	 https://www.therockcorner.com/tremonti
# Saving /Volumes/Biggy/Discog/artists-rockcorner/68/707324168.p (force=False)
#   --> This file is 10.2kB.
# Done. Sleeping for 30 seconds
# 11 / 14 	: 680031580 	 https://www.therockcorner.com/slade
# 12 / 14 	: 229742313 	 https://www.therockcorner.com/they-might-be-giants
# 13 / 14 	: 301810934 	 https://www.therockcorner.com/foo-fighters
# 14 / 14 	: 502460170 	 https://www.therockcorner.com/the-dandy-warhols
# ====> 38 / 3942   :  A Global Threat
#
#
# ===================== Searching For A Global Threat =====================
# Found 18 artists
# 1 / 18 	: 915481350 	 https://www.therockcorner.com/rise-against
# Saving /Volumes/Biggy/Discog/artists-rockcorner/50/915481350.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 30 seconds
# 2 / 18 	: 442776817 	 https://www.therockcorner.com/kreator
# 3 / 18 	: 15833670 	 https://www.therockcorner.com/david-bowie
# 4 / 18 	: 925907732 	 https://www.therockcorner.com/skid-row
# Saving /Volumes/Biggy/Discog/artists-rockcorner/32/925907732.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 30 seconds
# 5 / 18 	: 673770523 	 https://www.therockcorner.com/queensryche
# Saving /Volumes/Biggy/Discog/artists-rockcorner/23/673770523.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 30 seconds
# 6 / 18 	: 314691387 	 https://www.therockcorner.com/vangelis
# 7 / 18 	: 222684997 	 https://www.therockcorner.com/muddy-waters
# Saving /Volumes/Biggy/Discog/artists-rockcorner/97/222684997.p (force=False)
#   --> This file is 14.8kB.
# Done. Sleeping for 30 seconds
# 8 / 18 	: 412558713 	 https://www.therockcorner.com/the-animals
# Saving /Volumes/Biggy/Discog/artists-rockcorner/13/412558713.p (force=False)
#   --> This file is 15.5kB.
# Done. Sleeping for 30 seconds
# 9 / 18 	: 76148198 	 https://www.therockcorner.com/negativland
# Saving /Volumes/Biggy/Discog/artists-rockcorner/98/76148198.p (force=False)
#   --> This file is 16.1kB.
# Done. Sleeping for 30 seconds
# 10 / 18 	: 213257491 	 https://www.therockcorner.com/melvins
# 11 / 18 	: 773132441 	 https://www.therockcorner.com/johnny-cash
# 12 / 18 	: 517068174 	 https://www.therockcorner.com/the-tragically-hip
# 13 / 18 	: 350548651 	 https://www.therockcorner.com/afi
# 14 / 18 	: 841198073 	 https://www.therockcorner.com/megadeth
# Saving /Volumes/Biggy/Discog/artists-rockcorner/73/841198073.p (force=False)
#   --> This file is 16.4kB.
# Done. Sleeping for 30 seconds
# 15 / 18 	: 727598037 	 https://www.therockcorner.com/pennywise
# Saving /Volumes/Biggy/Discog/artists-rockcorner/37/727598037.p (force=False)
#   --> This file is 14.8kB.
# Done. Sleeping for 30 seconds
# 16 / 18 	: 192172830 	 https://www.therockcorner.com/iggy-pop
# 17 / 18 	: 155328240 	 https://www.therockcorner.com/gojira
# Saving /Volumes/Biggy/Discog/artists-rockcorner/40/155328240.p (force=False)
#   --> This file is 14.5kB.
# Done. Sleeping for 30 seconds
# 18 / 18 	: 62016462 	 https://www.therockcorner.com/the-strokes
# Saving /Volumes/Biggy/Discog/artists-rockcorner/62/62016462.p (force=False)
#   --> This file is 14.1kB.
# Done. Sleeping for 30 seconds
# ====> 39 / 3942   :  Amy Rigby
#
#
# ===================== Searching For Amy Rigby =====================
# Found 10 artists
# 1 / 10 	: 693617474 	 https://www.therockcorner.com/amy-winehouse
# 2 / 10 	: 860722327 	 https://www.therockcorner.com/cassia-eller
# Saving /Volumes/Biggy/Discog/artists-rockcorner/27/860722327.p (force=False)
#   --> This file is 15.7kB.
# Done. Sleeping for 30 seconds
# 3 / 10 	: 84783012 	 https://www.therockcorner.com/the-beatles
# Saving /Volumes/Biggy/Discog/artists-rockcorner/12/84783012.p (force=False)
#   --> This file is 16.7kB.
# Done. Sleeping for 30 seconds
# 4 / 10 	: 438479482 	 https://www.therockcorner.com/ray-charles
# Saving /Volumes/Biggy/Discog/artists-rockcorner/82/438479482.p (force=False)
#   --> This file is 15.8kB.
# Done. Sleeping for 30 seconds
# 5 / 10 	: 818975879 	 https://www.therockcorner.com/tangerine-dream
# 6 / 10 	: 402279133 	 https://www.therockcorner.com/paul-mc-cartney
# 7 / 10 	: 117010487 	 https://www.therockcorner.com/thrice
# Saving /Volumes/Biggy/Discog/artists-rockcorner/87/117010487.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 30 seconds
# 8 / 10 	: 954980477 	 https://www.therockcorner.com/kansas
# Saving /Volumes/Biggy/Discog/artists-rockcorner/77/954980477.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 30 seconds
# 9 / 10 	: 595380744 	 https://www.therockcorner.com/seether
# Saving /Volumes/Biggy/Discog/artists-rockcorner/44/595380744.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 30 seconds
# 10 / 10 	: 411558049 	 https://www.therockcorner.com/joan-baez
# ====> 40 / 3942   :  Anacrusis
#
#
# ===================== Searching For Anacrusis =====================
# Found 0 artists
# ====> 41 / 3942   :  Anata
#
#
# ===================== Searching For Anata =====================
# Found 3 artists
# 1 / 3 	: 566012679 	 https://www.therockcorner.com/l-arc-en-ciel
# Saving /Volumes/Biggy/Discog/artists-rockcorner/79/566012679.p (force=False)
#   --> This file is 14.2kB.
# Done. Sleeping for 30 seconds
# 2 / 3 	: 196836116 	 https://www.therockcorner.com/acid-black-cherry
# Saving /Volumes/Biggy/Discog/artists-rockcorner/16/196836116.p (force=False)
#   --> This file is 10.3kB.
# Done. Sleeping for 30 seconds
# 3 / 3 	: 562084804 	 https://www.therockcorner.com/b-z
# ====> 42 / 3942   :  Andre Williams
#
#
# ===================== Searching For Andre Williams =====================
# Found 3 artists
# 1 / 3 	: 79340108 	 https://www.therockcorner.com/lucinda-williams
# Saving /Volumes/Biggy/Discog/artists-rockcorner/8/79340108.p (force=False)
#   --> This file is 15.3kB.
# Done. Sleeping for 30 seconds
# 2 / 3 	: 373166793 	 https://www.therockcorner.com/zach-williams
# Saving /Volumes/Biggy/Discog/artists-rockcorner/93/373166793.p (force=False)
#   --> This file is 9.0kB.
# Done. Sleeping for 30 seconds
# 3 / 3 	: 730947063 	 https://www.therockcorner.com/deniece-williams
# Saving /Volumes/Biggy/Discog/artists-rockcorner/63/730947063.p (force=False)
#   --> This file is 8.7kB.
# Done. Sleeping for 30 seconds
# ====> 43 / 3942   :  Antichrisis
#
#
# ===================== Searching For Antichrisis =====================
# Found 0 artists
# ====> 44 / 3942   :  Apoptygma Berzerk
#
#
# ===================== Searching For Apoptygma Berzerk =====================
# Found 0 artists
# ====> 45 / 3942   :  Alison Moyet
#
#
# ===================== Searching For Alison Moyet =====================
# Found 2 artists
# 1 / 2 	: 274941644 	 https://www.therockcorner.com/alison-moyet
# Saving /Volumes/Biggy/Discog/artists-rockcorner/44/274941644.p (force=False)
#   --> This file is 14.7kB.
# Done. Sleeping for 30 seconds
# 2 / 2 	: 348975542 	 https://www.therockcorner.com/placebo
# Saving /Volumes/Biggy/Discog/artists-rockcorner/42/348975542.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 30 seconds
# ====> 46 / 3942   :  Amberian Dawn
#
#
# ===================== Searching For Amberian Dawn =====================
# Found 59 artists
# 1 / 59 	: 955189742 	 https://www.therockcorner.com/my-morning-jacket
# Saving /Volumes/Biggy/Discog/artists-rockcorner/42/955189742.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 30 seconds
# 2 / 59 	: 177977015 	 https://www.therockcorner.com/die-krupps
# Saving /Volumes/Biggy/Discog/artists-rockcorner/15/177977015.p (force=False)
#   --> This file is 16.0kB.
# Done. Sleeping for 30 seconds
# 3 / 59 	: 539215767 	 https://www.therockcorner.com/carlos-santana
# 4 / 59 	: 434630835 	 https://www.therockcorner.com/joy-division
# Saving /Volumes/Biggy/Discog/artists-rockcorner/35/434630835.p (force=False)
#   --> This file is 13.9kB.
# Done. Sleeping for 30 seconds
# 5 / 59 	: 710199802 	 https://www.therockcorner.com/slayer
# Saving /Volumes/Biggy/Discog/artists-rockcorner/2/710199802.p (force=False)
#   --> This file is 15.0kB.
# Done. Sleeping for 30 seconds
# 6 / 59 	: 679218361 	 https://www.therockcorner.com/cradle-of-filth
# 7 / 59 	: 314691387 	 https://www.therockcorner.com/vangelis
# 8 / 59 	: 154144701 	 https://www.therockcorner.com/the-rapture
# Saving /Volumes/Biggy/Discog/artists-rockcorner/1/154144701.p (force=False)
#   --> This file is 13.9kB.
# Done. Sleeping for 30 seconds
# 9 / 59 	: 933379275 	 https://www.therockcorner.com/manowar
# Saving /Volumes/Biggy/Discog/artists-rockcorner/75/933379275.p (force=False)
#   --> This file is 15.5kB.
# Done. Sleeping for 30 seconds
# 10 / 59 	: 818975879 	 https://www.therockcorner.com/tangerine-dream
# 11 / 59 	: 80032968 	 https://www.therockcorner.com/amon-amarth
# 12 / 59 	: 379231364 	 https://www.therockcorner.com/edwyn-collins
# Saving /Volumes/Biggy/Discog/artists-rockcorner/64/379231364.p (force=False)
#   --> This file is 14.5kB.
# Done. Sleeping for 30 seconds
# 13 / 59 	: 480933235 	 https://www.therockcorner.com/duncan-sheik
# Saving /Volumes/Biggy/Discog/artists-rockcorner/35/480933235.p (force=False)
#   --> This file is 14.4kB.
# Done. Sleeping for 30 seconds
# 14 / 59 	: 275065990 	 https://www.therockcorner.com/mono
# Saving /Volumes/Biggy/Discog/artists-rockcorner/90/275065990.p (force=False)
#   --> This file is 15.5kB.
# Done. Sleeping for 30 seconds
# 15 / 59 	: 117010487 	 https://www.therockcorner.com/thrice
# 16 / 59 	: 488687600 	 https://www.therockcorner.com/kamelot
# Saving /Volumes/Biggy/Discog/artists-rockcorner/0/488687600.p (force=False)
#   --> This file is 15.2kB.
# Done. Sleeping for 30 seconds
# 17 / 59 	: 621256296 	 https://www.therockcorner.com/the-church
# Saving /Volumes/Biggy/Discog/artists-rockcorner/96/621256296.p (force=False)
#   --> This file is 14.3kB.
# Done. Sleeping for 30 seconds
# 18 / 59 	: 699125758 	 https://www.therockcorner.com/in-flames
# Saving /Volumes/Biggy/Discog/artists-rockcorner/58/699125758.p (force=False)
#   --> This file is 15.2kB.
# Done. Sleeping for 30 seconds
# 19 / 59 	: 959761676 	 https://www.therockcorner.com/datarock
# Saving /Volumes/Biggy/Discog/artists-rockcorner/76/959761676.p (force=False)
#   --> This file is 9.3kB.
# Done. Sleeping for 30 seconds
# 20 / 59 	: 431392333 	 https://www.therockcorner.com/deicide
# 21 / 59 	: 224533173 	 https://www.therockcorner.com/michael-jackson
# 22 / 59 	: 77159476 	 https://www.therockcorner.com/judas-priest
# 23 / 59 	: 56500069 	 https://www.therockcorner.com/evanescence
# 24 / 59 	: 101808594 	 https://www.therockcorner.com/gordon-lightfoot
# 25 / 59 	: 705965581 	 https://www.therockcorner.com/breaking-benjamin
# Saving /Volumes/Biggy/Discog/artists-rockcorner/81/705965581.p (force=False)
#   --> This file is 14.1kB.
# Done. Sleeping for 30 seconds
# 26 / 59 	: 213257491 	 https://www.therockcorner.com/melvins
# 27 / 59 	: 157717264 	 https://www.therockcorner.com/Buckethead
# 28 / 59 	: 205909279 	 https://www.therockcorner.com/the-weakerthans
# Saving /Volumes/Biggy/Discog/artists-rockcorner/79/205909279.p (force=False)
#   --> This file is 12.4kB.
# Done. Sleeping for 30 seconds
# 29 / 59 	: 294575720 	 https://www.therockcorner.com/wilco
# Saving /Volumes/Biggy/Discog/artists-rockcorner/20/294575720.p (force=False)
#   --> This file is 14.7kB.
# Done. Sleeping for 30 seconds
# 30 / 59 	: 103591349 	 https://www.therockcorner.com/prince
# 31 / 59 	: 23767610 	 https://www.therockcorner.com/the-pillows
# Saving /Volumes/Biggy/Discog/artists-rockcorner/10/23767610.p (force=False)
#   --> This file is 15.5kB.
# Done. Sleeping for 30 seconds
# 32 / 59 	: 722001724 	 https://www.therockcorner.com/unknown-mortal-orchestra
# Saving /Volumes/Biggy/Discog/artists-rockcorner/24/722001724.p (force=False)
#   --> This file is 10.6kB.
# Done. Sleeping for 30 seconds
# 33 / 59 	: 812425269 	 https://www.therockcorner.com/yes
# 34 / 59 	: 18066148 	 https://www.therockcorner.com/van-morrison
# 35 / 59 	: 300941147 	 https://www.therockcorner.com/galneryus
# 36 / 59 	: 494630645 	 https://www.therockcorner.com/30-seconds-to-mars
# Saving /Volumes/Biggy/Discog/artists-rockcorner/45/494630645.p (force=False)
#   --> This file is 14.4kB.
# Done. Sleeping for 30 seconds
# 37 / 59 	: 822497256 	 https://www.therockcorner.com/before-their-eyes
# Saving /Volumes/Biggy/Discog/artists-rockcorner/56/822497256.p (force=False)
#   --> This file is 11.5kB.
# Done. Sleeping for 30 seconds
# 38 / 59 	: 237927403 	 https://www.therockcorner.com/yngwie-malmsteen
# Saving /Volumes/Biggy/Discog/artists-rockcorner/3/237927403.p (force=False)
#   --> This file is 16.6kB.
# Done. Sleeping for 30 seconds
# 39 / 59 	: 623315634 	 https://www.therockcorner.com/pelican
# Saving /Volumes/Biggy/Discog/artists-rockcorner/34/623315634.p (force=False)
#   --> This file is 12.2kB.
# Done. Sleeping for 30 seconds
# 40 / 59 	: 173505339 	 https://www.therockcorner.com/six-feet-under
# 41 / 59 	: 333274684 	 https://www.therockcorner.com/u-d-o
# Saving /Volumes/Biggy/Discog/artists-rockcorner/84/333274684.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 30 seconds
# 42 / 59 	: 631771879 	 https://www.therockcorner.com/tiamat
# 43 / 59 	: 8856672 	 https://www.therockcorner.com/edguy
# Saving /Volumes/Biggy/Discog/artists-rockcorner/72/8856672.p (force=False)
#   --> This file is 12.3kB.
# Done. Sleeping for 30 seconds
# 44 / 59 	: 389717926 	 https://www.therockcorner.com/ministry
# Saving /Volumes/Biggy/Discog/artists-rockcorner/26/389717926.p (force=False)
#   --> This file is 15.5kB.
# Done. Sleeping for 30 seconds
# 45 / 59 	: 769687932 	 https://www.therockcorner.com/tortoise
# Saving /Volumes/Biggy/Discog/artists-rockcorner/32/769687932.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 30 seconds
# 46 / 59 	: 295317559 	 https://www.therockcorner.com/pink-floyd
# Saving /Volumes/Biggy/Discog/artists-rockcorner/59/295317559.p (force=False)
#   --> This file is 15.4kB.
# Done. Sleeping for 30 seconds
# 47 / 59 	: 367197868 	 https://www.therockcorner.com/damon-albarn
# Saving /Volumes/Biggy/Discog/artists-rockcorner/68/367197868.p (force=False)
#   --> This file is 14.0kB.
# Done. Sleeping for 30 seconds

# %%
def getMyMusicDBMap():
    myMusicMap = getFile(ifile="/Users/tgadfort/Documents/code/music/myMusicMap.p")
    print("Found {0} entries".format(len(myMusicMap)))
    return myMusicMap

myMusicMap = getMyMusicDBMap()

# %%
def downloadSearchResults(maxI=-1):
    for i,artistName in enumerate(myMusicMap.keys()):
        if i <= maxI:
            continue
        print("====>",i,"/",len(myMusicMap),"  : ",artistName)
#        try:
        artsLM.searchLastFMForArtist(artistName, sleeptime=3)
#        except:
#            sleep(3)
        sleep(3)

# %%
downloadSearchResults(3544)

# %% [markdown]
# # Download Extra Artist Files

# %%
#artsLM.assertDBModValExtraData(1, maxPages=3)

# %%
from random import shuffle
modVals = list(range(100))
shuffle(modVals)
for modVal in modVals:
    try:
        artsLM.assertDBModValExtraData(modVal, maxPages=3)
    except:
        continue

# %%
artsLM.assertDBModValExtraData(61)

# %%
retval = artLM.getData("/Volumes/Biggy/Discog/artists-lastfm/51/34806831451.p")

# %%
artsLM.parseArtistFiles()

# %%
dutils.getArtistID("Coldplay vs. The Killers vs. Kelly Clarkson vs. Bon Jovi vs. Empire Of The Sun vs. Muse")  # 99596595167
dutils.getArtistID("Coldplay vs. The Killers vs. Kelly Clarkson vs. Bon…")   # 93496498096

# %%
url="https://www.last.fm/search/artists?q=Coldplay"
savename="lm_search.p"
artsLM.downloadArtistURL(url=url, savename=savename)

# %%
bsdata = getHTML("lm_search.p")

# %%
uls = bsdata.findAll("ul", {"class": "artist-results"})
for ul in uls:
    lis = ul.findAll("li", {"class": "artist-result"})
    for li in lis:
        h4 = li.find("h4")
        if h4 is None:
            raise ValueError("No h4 in list")
        result   = artLM.getNamesAndURLs(h4)
        name     = result[0].name
        url      = result[0].url
        artistID = dutils.getArtistID(name)
        print(name,'\t',url,'\t',artistID)

# %%
#bsdata

# %%
retval = artLM.getData("lastfm.p")

# %%
retval.artist.get()

# %%
retval.pages.get()

# %%
retval.url.get()

# %%
retval.ID.get()

# %%
retval.profile.get()

# %%
for album in retval.media.media["Albums"]:
    print(album.get())

# %%
retval.mediaCounts.get()

# %%
# %load_ext autoreload
# %autoreload
disc = discogs('lastfm')
arts = artists(disc)
#arts.searchDiscogForArtist("The Whispers")

# %%
from webUtils import getWebData
url="https://www.last.fm/music/Coldplay/+albums"
url="https://www.last.fm/music/Coldplay/+albums?order=release_date"
url="https://www.last.fm/music/Coldplay/+albums?order=release_date"
savename="lastfm.p"
getWebData(base=url, savename=savename, useSafari=False)

# %%
url="https://www.datpiff.com/mixtapes-search?criteria=yo%20gotti&sort=relevance"
savename = "dp_search.p"
getWebData(base=url, savename=savename, useSafari=False)

# %%
getWebData

# %%
bsdata = getHTML("dp_search.p")

# %%
bsdata

# %%
contentdivs = bsdata.findAll("div", {"class": "contentItem"})
for i,contentdiv in enumerate(contentdivs):
    artistDiv = contentdiv.find("div", {"class": "artist"})
    if artistDiv is None:
        raise ValueError("There is no artist div")
    artistName = artistDiv.text
    
    albumDiv = contentdiv.find("div", {"class": "title"})
    if albumDiv is None:
        raise ValueError("There is no title div")
    albumName = albumDiv.text
    try:
        albumURL  = albumDiv.find("a").attrs['href']
    except:
        albumURL  = None
        
    print(artistName,'\t',albumName)

# %%
divs[1]
