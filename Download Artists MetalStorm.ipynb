# %% [markdown]
# # MetalStorm

# %%
######################################################
# Juypter
######################################################
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))


######################################################
# General
######################################################
from ioUtils import saveJoblib, loadJoblib, saveFile, getFile
import urllib
from urllib.parse import quote
from collection import collections
from artist import artist
from timeUtils import clock, elapsed
from fsUtils import moveFile, setFile, setDir, setSubDir, isFile, isDir, mkDir
from ioUtils import getFile, saveFile
from fileUtils import getFileBasics, getBasename
from webUtils import getWebData, getHTML, getURL
from time import sleep
import time
from multiprocessing import Pool


######################################################
# Music Stuff
######################################################
from discogsBase import discogs
from artistMT import artistMT
from artistsMT import artistsMT
from discogsUtils import metalstormUtils
from multiArtist import multiartist
from myMusicDBMap import myMusicDBMap


######################################################
# Versions
######################################################
import sys
print("Python: {0}".format(sys.version))
import datetime as dt
start = dt.datetime.now()
print("Notebook Last Run Initiated: "+str(start))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# Python: 3.7.3 (default, Mar 27 2019, 16:54:48)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# Notebook Last Run Initiated: 2020-04-12 12:51:02.146891

# %% [markdown]
# # Initialize

# %%
# %load_ext autoreload
# %autoreload
discMT = discogs('metalstorm')
dutils = metalstormUtils()
#artMS  = artistMS()
#artsMS = artistsMS(discMS)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # My Music

# %%
mdb = myMusicDBMap(debug=True)

# %% [markdown]
# # Search

# %%
from ioUtils import getFile, saveFile
from searchUtils import findPatternExt
from fileUtils import getBaseFilename

artMS = artistMS()
files = findPatternExt("/Users/tgadfort/Downloads/", pattern="MusicStack", ext=".html")
for ifile in files:
    fname  = getBaseFilename(ifile)
    artist = fname[:fname.find(" Vinyl Records")]
    artsMS.searchMusicStackForArtist(artist=artist, data=ifile, debug=False)

# %% [markdown]
# # Download All Music

# %%
def downloadMusicStackArtists(minI=-1):
    artists = mdb.getArtists()
    for i,artistName in enumerate(artists):
        if i <= minI:
            continue
        print("====>",i,"/",len(artists),"  : ",artistName)
        artsMS.searchMusicStackForArtist(artistName, sleeptime=15)
        break

# %%
downloadMusicStackArtists(0)

# %%
for i,searchTerm in enumerate(searchTerms):
    print("\n=====>",i,"/",len(searchTerms),"==>",searchTerm)
    artsMS.searchRateYouDPusicForArtist(searchTerm)
    known.append(searchTerm)
    sleep(3)

# %% [markdown]
# # Initialize

# %%
# %load_ext autoreload
# %autoreload
discMS = discogs('musicstack')
dutils = cdandlpUtils()
artMS  = artistMS()
artsMS = artistsMS(discMS)

# %% [markdown]
# # Music DB

# %%
mdb = myMusicDBMap(debug=True)

# %% [markdown]
# # Search

# %%
#artsCL.searchCDandLPForArtist("Anal Cunt", data=data)

# %% [markdown]
# # Download All Music

# %%
def downloadCDandLPArtists(minI=-1):
    artists = mdb.getArtists()
    for i,artistName in enumerate(artists):
        if i <= minI:
            continue
        print("====>",i,"/",len(artists),"  : ",artistName)
        artsCL.searchCDandLPForArtist(artistName, sleeptime=15)

# %%
downloadCDandLPArtists(1)

# %%
#data = getFile("Search A Flock Of Seagulls on CDandLP.html")
url="http://www.metalstorm.net/bands/discography.php?band_id=10281&bandname=Crawl"
savename="metalstorm.p"
artsMS.downloadArtistURL(url, savename)

# %%
#bsdata = getHTML("/Users/tgadfort/Downloads/Featured bands - Metal Storm.html")
#artMT = artistMT()

# %%
#http://www.metalstorm.net/bands/index.php?b_sortby=&b_where=&b_what=&page=3

# %%
# %load_ext autoreload
# %autoreload
discMT = discogs('metalstorm')
dutils = metalstormUtils()
artMT = artistMT()
artsMT = artistsMT(discMT)
#artsMT.downloadSiteIndex(sleeptime=5)
artsMT.downloadArtistsFromIndex(sleeptime=5)
#retval = artMT.getData("metalstorm.p")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index1.p
# <artistMT.artistMTURLInfo object at 0x1a264bb630>
# band.php?band_id=60
# <artistMT.artistMTURLInfo object at 0x1a264bb748>
# band.php?band_id=13
# <artistMT.artistMTURLInfo object at 0x1a264bb668>
# band.php?band_id=176
# <artistMT.artistMTURLInfo object at 0x1a264bb6a0>
# band.php?band_id=163
# <artistMT.artistMTURLInfo object at 0x1a264bb630>
# band.php?band_id=25
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=183
# <artistMT.artistMTURLInfo object at 0x1a264bb780>
# band.php?band_id=83
# <artistMT.artistMTURLInfo object at 0x1a264bb6a0>
# band.php?band_id=52
# <artistMT.artistMTURLInfo object at 0x1a264bb630>
# band.php?band_id=92
# <artistMT.artistMTURLInfo object at 0x1a264bb5f8>
# band.php?band_id=78
# <artistMT.artistMTURLInfo object at 0x1a264bb668>
# band.php?band_id=1
# <artistMT.artistMTURLInfo object at 0x1a264bb6a0>
# band.php?band_id=72
# <artistMT.artistMTURLInfo object at 0x1a264bb630>
# band.php?band_id=53
# <artistMT.artistMTURLInfo object at 0x1a264bb748>
# band.php?band_id=80
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=58
# <artistMT.artistMTURLInfo object at 0x1a264bb6a0>
# band.php?band_id=296
# <artistMT.artistMTURLInfo object at 0x1a264bb630>
# band.php?band_id=61
# <artistMT.artistMTURLInfo object at 0x1a264bb748>
# band.php?band_id=95
# <artistMT.artistMTURLInfo object at 0x1a264bb668>
# band.php?band_id=50
# <artistMT.artistMTURLInfo object at 0x1a264bb6a0>
# band.php?band_id=137
# <artistMT.artistMTURLInfo object at 0x1a264bb630>
# band.php?band_id=42
# <artistMT.artistMTURLInfo object at 0x1a264bb780>
# band.php?band_id=142
# <artistMT.artistMTURLInfo object at 0x1a264bb668>
# band.php?band_id=86
# <artistMT.artistMTURLInfo object at 0x1a264bb6a0>
# band.php?band_id=384
# <artistMT.artistMTURLInfo object at 0x1a264bb630>
# band.php?band_id=425
# <artistMT.artistMTURLInfo object at 0x1a264bb748>
# band.php?band_id=26
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=495
# <artistMT.artistMTURLInfo object at 0x1a264bb6a0>
# band.php?band_id=181
# <artistMT.artistMTURLInfo object at 0x1a264bb630>
# band.php?band_id=123
# <artistMT.artistMTURLInfo object at 0x1a264bb748>
# band.php?band_id=136
# <artistMT.artistMTURLInfo object at 0x1a264bb780>
# band.php?band_id=124
# <artistMT.artistMTURLInfo object at 0x1a264bb630>
# band.php?band_id=475
# <artistMT.artistMTURLInfo object at 0x1a264bb7f0>
# band.php?band_id=208
# <artistMT.artistMTURLInfo object at 0x1a264bb6d8>
# band.php?band_id=294
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=2
# <artistMT.artistMTURLInfo object at 0x1a264bb5f8>
# band.php?band_id=28
# <artistMT.artistMTURLInfo object at 0x1a264bb7b8>
# band.php?band_id=1064
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=167
# <artistMT.artistMTURLInfo object at 0x1a264bb7f0>
# band.php?band_id=349
# <artistMT.artistMTURLInfo object at 0x1a264bb5f8>
# band.php?band_id=15
# <artistMT.artistMTURLInfo object at 0x1a264bb7b8>
# band.php?band_id=151
# <artistMT.artistMTURLInfo object at 0x1a264bb6d8>
# band.php?band_id=97
# <artistMT.artistMTURLInfo object at 0x1a264bb7f0>
# band.php?band_id=172
# <artistMT.artistMTURLInfo object at 0x1a264bb748>
# band.php?band_id=94
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=166
# <artistMT.artistMTURLInfo object at 0x1a264bb6d8>
# band.php?band_id=68
# <artistMT.artistMTURLInfo object at 0x1a264bb7b8>
# band.php?band_id=130
# <artistMT.artistMTURLInfo object at 0x1a264bb748>
# band.php?band_id=2346
# <artistMT.artistMTURLInfo object at 0x1a264bb5f8>
# band.php?band_id=6
# <artistMT.artistMTURLInfo object at 0x1a264bb6d8>
# band.php?band_id=59
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index10.p
# <artistMT.artistMTURLInfo object at 0x1a264bb4e0>
# band.php?band_id=4557
# <artistMT.artistMTURLInfo object at 0x1a264bb4a8>
# band.php?band_id=1618
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=144
# <artistMT.artistMTURLInfo object at 0x1a264bb518>
# band.php?band_id=510
# <artistMT.artistMTURLInfo object at 0x1a264bb4a8>
# band.php?band_id=3170
# <artistMT.artistMTURLInfo object at 0x1a264bb5c0>
# band.php?band_id=492
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=2265
# <artistMT.artistMTURLInfo object at 0x1a264bb518>
# band.php?band_id=2333
# <artistMT.artistMTURLInfo object at 0x1a264bb4a8>
# band.php?band_id=34
# <artistMT.artistMTURLInfo object at 0x1a264bb4e0>
# band.php?band_id=3247
# <artistMT.artistMTURLInfo object at 0x1a264bb6d8>
# band.php?band_id=4538
# <artistMT.artistMTURLInfo object at 0x1a264bb518>
# band.php?band_id=687
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=1589
# <artistMT.artistMTURLInfo object at 0x1a264bb4e0>
# band.php?band_id=1223
# <artistMT.artistMTURLInfo object at 0x1a264bb6d8>
# band.php?band_id=305
# <artistMT.artistMTURLInfo object at 0x1a264bb518>
# band.php?band_id=6020
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=4251
# <artistMT.artistMTURLInfo object at 0x1a264bb4e0>
# band.php?band_id=3569
# <artistMT.artistMTURLInfo object at 0x1a264bb6d8>
# band.php?band_id=119
# <artistMT.artistMTURLInfo object at 0x1a264bb4a8>
# band.php?band_id=1607
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=4667
# <artistMT.artistMTURLInfo object at 0x1a264bb4e0>
# band.php?band_id=360
# <artistMT.artistMTURLInfo object at 0x1a264bb6d8>
# band.php?band_id=3420
# <artistMT.artistMTURLInfo object at 0x1a264bb4a8>
# band.php?band_id=6861
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=7192
# <artistMT.artistMTURLInfo object at 0x1a264bb7b8>
# band.php?band_id=3402
# <artistMT.artistMTURLInfo object at 0x1a264bb6d8>
# band.php?band_id=994
# <artistMT.artistMTURLInfo object at 0x1a264bb5c0>
# band.php?band_id=3040
# <artistMT.artistMTURLInfo object at 0x1a264bb4e0>
# band.php?band_id=194
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=7057
# <artistMT.artistMTURLInfo object at 0x1a264bb6d8>
# band.php?band_id=2626
# <artistMT.artistMTURLInfo object at 0x1a264bb4a8>
# band.php?band_id=941
# <artistMT.artistMTURLInfo object at 0x1a264bb4e0>
# band.php?band_id=3
# <artistMT.artistMTURLInfo object at 0x1a264bb6d8>
# band.php?band_id=9162
# <artistMT.artistMTURLInfo object at 0x1a264bb5c0>
# band.php?band_id=2516
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=196
# <artistMT.artistMTURLInfo object at 0x1a264bb4e0>
# band.php?band_id=965
# <artistMT.artistMTURLInfo object at 0x1a264bb6d8>
# band.php?band_id=503
# <artistMT.artistMTURLInfo object at 0x1a264bb5c0>
# band.php?band_id=2821
# <artistMT.artistMTURLInfo object at 0x1a264bb4a8>
# band.php?band_id=178
# <artistMT.artistMTURLInfo object at 0x1a264bb7b8>
# band.php?band_id=480
# <artistMT.artistMTURLInfo object at 0x1a264bb4e0>
# band.php?band_id=1079
# <artistMT.artistMTURLInfo object at 0x1a264bb5c0>
# band.php?band_id=511
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=180
# <artistMT.artistMTURLInfo object at 0x1a264bb7b8>
# band.php?band_id=3156
# <artistMT.artistMTURLInfo object at 0x1a264bb6d8>
# band.php?band_id=2772
# <artistMT.artistMTURLInfo object at 0x1a264bb4a8>
# band.php?band_id=242
# <artistMT.artistMTURLInfo object at 0x1a264bb710>
# band.php?band_id=221
# <artistMT.artistMTURLInfo object at 0x1a264bb7b8>
# band.php?band_id=432
# <artistMT.artistMTURLInfo object at 0x1a264bb4a8>
# band.php?band_id=2701
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index100.p
# <artistMT.artistMTURLInfo object at 0x1a2654b128>
# band.php?band_id=10169
# <artistMT.artistMTURLInfo object at 0x1a2654bb38>
# band.php?band_id=10249
# <artistMT.artistMTURLInfo object at 0x1a2654bac8>
# band.php?band_id=3389
# <artistMT.artistMTURLInfo object at 0x1a2654ba90>
# band.php?band_id=10611
# <artistMT.artistMTURLInfo object at 0x1a2654b128>
# band.php?band_id=7555
# <artistMT.artistMTURLInfo object at 0x1a2654bb38>
# band.php?band_id=9243
# <artistMT.artistMTURLInfo object at 0x1a2654b278>
# band.php?band_id=3745
# <artistMT.artistMTURLInfo object at 0x1a2654ba90>
# band.php?band_id=10417
# <artistMT.artistMTURLInfo object at 0x1a2654b128>
# band.php?band_id=5417
# <artistMT.artistMTURLInfo object at 0x1a2654b048>
# band.php?band_id=9870
# <artistMT.artistMTURLInfo object at 0x1a264bb4a8>
# band.php?band_id=9374
# <artistMT.artistMTURLInfo object at 0x1a2654bb38>
# band.php?band_id=10285
# <artistMT.artistMTURLInfo object at 0x1a2654b128>
# band.php?band_id=1323
# <artistMT.artistMTURLInfo object at 0x1a2654bac8>
# band.php?band_id=8719
# <artistMT.artistMTURLInfo object at 0x1a2654b278>
# band.php?band_id=8327
# <artistMT.artistMTURLInfo object at 0x1a2654b048>
# band.php?band_id=11333
# <artistMT.artistMTURLInfo object at 0x1a264bb4a8>
# band.php?band_id=7501
# <artistMT.artistMTURLInfo object at 0x1a2654bac8>
# band.php?band_id=6467
# <artistMT.artistMTURLInfo object at 0x1a2654b128>
# band.php?band_id=5508
# <artistMT.artistMTURLInfo object at 0x1a2654ba90>
# band.php?band_id=9837
# <artistMT.artistMTURLInfo object at 0x1a2654bb38>
# band.php?band_id=5671
# <artistMT.artistMTURLInfo object at 0x1a2654bac8>
# band.php?band_id=6339
# <artistMT.artistMTURLInfo object at 0x1a2654b278>
# band.php?band_id=7916
# <artistMT.artistMTURLInfo object at 0x1a2654b048>
# band.php?band_id=8950
# <artistMT.artistMTURLInfo object at 0x1a2654bb38>
# band.php?band_id=8218
# <artistMT.artistMTURLInfo object at 0x1a2654bac8>
# band.php?band_id=9055
# <artistMT.artistMTURLInfo object at 0x1a2654b128>
# band.php?band_id=10407
# <artistMT.artistMTURLInfo object at 0x1a2654ba90>
# band.php?band_id=5756
# <artistMT.artistMTURLInfo object at 0x1a2654bb38>
# band.php?band_id=7419
# <artistMT.artistMTURLInfo object at 0x1a2654bac8>
# band.php?band_id=8404
# <artistMT.artistMTURLInfo object at 0x1a2654b278>
# band.php?band_id=11023
# <artistMT.artistMTURLInfo object at 0x1a2654b048>
# band.php?band_id=1174
# <artistMT.artistMTURLInfo object at 0x1a264bb4a8>
# band.php?band_id=8488
# <artistMT.artistMTURLInfo object at 0x1a2654ba90>
# band.php?band_id=9235
# <artistMT.artistMTURLInfo object at 0x1a264bb4a8>
# band.php?band_id=9959
# <artistMT.artistMTURLInfo object at 0x1a2654b128>
# band.php?band_id=1685
# <artistMT.artistMTURLInfo object at 0x1a2654b048>
# band.php?band_id=3637
# <artistMT.artistMTURLInfo object at 0x1a264bb4a8>
# band.php?band_id=10070
# <artistMT.artistMTURLInfo object at 0x1a2654b278>
# band.php?band_id=10123
# <artistMT.artistMTURLInfo object at 0x1a2654b128>
# band.php?band_id=9878
# <artistMT.artistMTURLInfo object at 0x1a2654bb38>
# band.php?band_id=11478
# <artistMT.artistMTURLInfo object at 0x1a2654b048>
# band.php?band_id=11513
# <artistMT.artistMTURLInfo object at 0x1a2654b278>
# band.php?band_id=8145
# <artistMT.artistMTURLInfo object at 0x1a2654b128>
# band.php?band_id=10935
# <artistMT.artistMTURLInfo object at 0x1a2654bac8>
# band.php?band_id=10482
# <artistMT.artistMTURLInfo object at 0x1a2654ba90>
# band.php?band_id=969
# <artistMT.artistMTURLInfo object at 0x1a265739e8>
# band.php?band_id=11393
# <artistMT.artistMTURLInfo object at 0x1a2654b128>
# band.php?band_id=5786
# <artistMT.artistMTURLInfo object at 0x1a2654bac8>
# band.php?band_id=5089
# <artistMT.artistMTURLInfo object at 0x1a2654b048>
# band.php?band_id=11374
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index101.p
# <artistMT.artistMTURLInfo object at 0x1a259c5518>
# band.php?band_id=9627
# <artistMT.artistMTURLInfo object at 0x1a259c5550>
# band.php?band_id=4292
# <artistMT.artistMTURLInfo object at 0x1a259c55c0>
# band.php?band_id=3504
# <artistMT.artistMTURLInfo object at 0x1a259c54e0>
# band.php?band_id=10714
# <artistMT.artistMTURLInfo object at 0x1a259c5518>
# band.php?band_id=10466
# <artistMT.artistMTURLInfo object at 0x1a259c54a8>
# band.php?band_id=5843
# <artistMT.artistMTURLInfo object at 0x1a259c55c0>
# band.php?band_id=3733
# <artistMT.artistMTURLInfo object at 0x1a259c5550>
# band.php?band_id=5625
# <artistMT.artistMTURLInfo object at 0x1a259c54a8>
# band.php?band_id=4524
# <artistMT.artistMTURLInfo object at 0x1a259c5518>
# band.php?band_id=11238
# <artistMT.artistMTURLInfo object at 0x1a259c55c0>
# band.php?band_id=10681
# <artistMT.artistMTURLInfo object at 0x1a259c54a8>
# band.php?band_id=9589
# <artistMT.artistMTURLInfo object at 0x1a259c5550>
# band.php?band_id=7050
# <artistMT.artistMTURLInfo object at 0x1a259c5518>
# band.php?band_id=9756
# <artistMT.artistMTURLInfo object at 0x1a259c54a8>
# band.php?band_id=9554
# <artistMT.artistMTURLInfo object at 0x1a259c55c0>
# band.php?band_id=9071
# <artistMT.artistMTURLInfo object at 0x1a259c5550>
# band.php?band_id=3890
# <artistMT.artistMTURLInfo object at 0x1a259c54a8>
# band.php?band_id=1500
# <artistMT.artistMTURLInfo object at 0x1a259c5518>
# band.php?band_id=10140
# <artistMT.artistMTURLInfo object at 0x1a259c55c0>
# band.php?band_id=864
# <artistMT.artistMTURLInfo object at 0x1a259c54a8>
# band.php?band_id=10036
# <artistMT.artistMTURLInfo object at 0x1a259c5550>
# band.php?band_id=8009
# <artistMT.artistMTURLInfo object at 0x1a259c5518>
# band.php?band_id=9999
# <artistMT.artistMTURLInfo object at 0x1a259c5438>
# band.php?band_id=3731
# <artistMT.artistMTURLInfo object at 0x1a2654b048>
# band.php?band_id=9366
# <artistMT.artistMTURLInfo object at 0x1a259c5550>
# band.php?band_id=10918
# <artistMT.artistMTURLInfo object at 0x1a259c5518>
# band.php?band_id=8470
# <artistMT.artistMTURLInfo object at 0x1a259c54a8>
# band.php?band_id=8850
# <artistMT.artistMTURLInfo object at 0x1a259c5550>
# band.php?band_id=1027
# <artistMT.artistMTURLInfo object at 0x1a259c5518>
# band.php?band_id=6075
# <artistMT.artistMTURLInfo object at 0x1a259c54a8>
# band.php?band_id=5873
# <artistMT.artistMTURLInfo object at 0x1a259c5550>
# band.php?band_id=6417
# <artistMT.artistMTURLInfo object at 0x1a259c55c0>
# band.php?band_id=5852
# <artistMT.artistMTURLInfo object at 0x1a26927240>
# band.php?band_id=10507
# <artistMT.artistMTURLInfo object at 0x1a259c55c0>
# band.php?band_id=8821
# <artistMT.artistMTURLInfo object at 0x1a259c54a8>
# band.php?band_id=7062
# <artistMT.artistMTURLInfo object at 0x1a26583048>
# band.php?band_id=7620
# <artistMT.artistMTURLInfo object at 0x1a259c54a8>
# band.php?band_id=10260
# <artistMT.artistMTURLInfo object at 0x1a259c5518>
# band.php?band_id=7278
# <artistMT.artistMTURLInfo object at 0x1a259c55c0>
# band.php?band_id=8914
# <artistMT.artistMTURLInfo object at 0x1a259c54a8>
# band.php?band_id=9988
# <artistMT.artistMTURLInfo object at 0x1a259c5550>
# band.php?band_id=9799
# <artistMT.artistMTURLInfo object at 0x1a2654b048>
# band.php?band_id=10346
# <artistMT.artistMTURLInfo object at 0x1a259c5550>
# band.php?band_id=5939
# <artistMT.artistMTURLInfo object at 0x1a259c5518>
# band.php?band_id=8481
# <artistMT.artistMTURLInfo object at 0x1a259c54a8>
# band.php?band_id=3618
# <artistMT.artistMTURLInfo object at 0x1a259c5550>
# band.php?band_id=8889
# <artistMT.artistMTURLInfo object at 0x1a259c5518>
# band.php?band_id=5877
# <artistMT.artistMTURLInfo object at 0x1a259c55c0>
# band.php?band_id=10281
# <artistMT.artistMTURLInfo object at 0x1a265739e8>
# band.php?band_id=9659
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index102.p
# <artistMT.artistMTURLInfo object at 0x1a26389d30>
# band.php?band_id=2066
# <artistMT.artistMTURLInfo object at 0x1a26389eb8>
# band.php?band_id=9358
# <artistMT.artistMTURLInfo object at 0x1a26389390>
# band.php?band_id=7436
# <artistMT.artistMTURLInfo object at 0x1a26389ac8>
# band.php?band_id=9590
# <artistMT.artistMTURLInfo object at 0x1a26389390>
# band.php?band_id=11378
# <artistMT.artistMTURLInfo object at 0x1a26389d30>
# band.php?band_id=635
# <artistMT.artistMTURLInfo object at 0x1a26389ac8>
# band.php?band_id=9048
# <artistMT.artistMTURLInfo object at 0x1a26389390>
# band.php?band_id=6229
# <artistMT.artistMTURLInfo object at 0x1a26389d30>
# band.php?band_id=11464
# <artistMT.artistMTURLInfo object at 0x1a26389eb8>
# band.php?band_id=10350
# <artistMT.artistMTURLInfo object at 0x1a26389390>
# band.php?band_id=10924
# <artistMT.artistMTURLInfo object at 0x1a26389eb8>
# band.php?band_id=9802
# <artistMT.artistMTURLInfo object at 0x1a26389ac8>
# band.php?band_id=11375
# <artistMT.artistMTURLInfo object at 0x1a26389390>
# band.php?band_id=9019
# <artistMT.artistMTURLInfo object at 0x1a26389eb8>
# band.php?band_id=7783
# <artistMT.artistMTURLInfo object at 0x1a26389ac8>
# band.php?band_id=924
# <artistMT.artistMTURLInfo object at 0x1a26389390>
# band.php?band_id=8722
# <artistMT.artistMTURLInfo object at 0x1a26389eb8>
# band.php?band_id=844
# <artistMT.artistMTURLInfo object at 0x1a26389ac8>
# band.php?band_id=9061
# <artistMT.artistMTURLInfo object at 0x1a26389390>
# band.php?band_id=11391
# <artistMT.artistMTURLInfo object at 0x1a26389eb8>
# band.php?band_id=4852
# <artistMT.artistMTURLInfo object at 0x1a26389ac8>
# band.php?band_id=6581
# <artistMT.artistMTURLInfo object at 0x1a26389390>
# band.php?band_id=10725
# <artistMT.artistMTURLInfo object at 0x1a26389d30>
# band.php?band_id=8919
# <artistMT.artistMTURLInfo object at 0x1a26389ac8>
# band.php?band_id=8554
# <artistMT.artistMTURLInfo object at 0x1a26389390>
# band.php?band_id=9356
# <artistMT.artistMTURLInfo object at 0x1a26389eb8>
# band.php?band_id=5467
# <artistMT.artistMTURLInfo object at 0x1a26389390>
# band.php?band_id=7956
# <artistMT.artistMTURLInfo object at 0x1a26389d30>
# band.php?band_id=2642
# <artistMT.artistMTURLInfo object at 0x1a26389eb8>
# band.php?band_id=8579
# <artistMT.artistMTURLInfo object at 0x1a26389ac8>
# band.php?band_id=8329
# <artistMT.artistMTURLInfo object at 0x1a26389668>
# band.php?band_id=9025
# <artistMT.artistMTURLInfo object at 0x1a26389ac8>
# band.php?band_id=7218
# <artistMT.artistMTURLInfo object at 0x1a26389668>
# band.php?band_id=10218
# <artistMT.artistMTURLInfo object at 0x1a26389d30>
# band.php?band_id=2181
# <artistMT.artistMTURLInfo object at 0x1a26389ac8>
# band.php?band_id=11586
# <artistMT.artistMTURLInfo object at 0x1a26389390>
# band.php?band_id=10081
# <artistMT.artistMTURLInfo object at 0x1a26389d30>
# band.php?band_id=10265
# <artistMT.artistMTURLInfo object at 0x1a26389ac8>
# band.php?band_id=10929
# <artistMT.artistMTURLInfo object at 0x1a26389668>
# band.php?band_id=8775
# <artistMT.artistMTURLInfo object at 0x1a26389d30>
# band.php?band_id=10888
# <artistMT.artistMTURLInfo object at 0x1a26389390>
# band.php?band_id=10084
# <artistMT.artistMTURLInfo object at 0x1a26389d30>
# band.php?band_id=2109
# <artistMT.artistMTURLInfo object at 0x1a26389668>
# band.php?band_id=8584
# <artistMT.artistMTURLInfo object at 0x1a26389d30>
# band.php?band_id=8437
# <artistMT.artistMTURLInfo object at 0x1a26389668>
# band.php?band_id=676
# <artistMT.artistMTURLInfo object at 0x1a26389390>
# band.php?band_id=11353
# <artistMT.artistMTURLInfo object at 0x1a26389d30>
# band.php?band_id=3666
# <artistMT.artistMTURLInfo object at 0x1a26389668>
# band.php?band_id=10221
# <artistMT.artistMTURLInfo object at 0x1a26389ac8>
# band.php?band_id=6492
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index103.p
# <artistMT.artistMTURLInfo object at 0x1a26b06668>
# band.php?band_id=9839
# <artistMT.artistMTURLInfo object at 0x1a26b066a0>
# band.php?band_id=9211
# <artistMT.artistMTURLInfo object at 0x1a26b06710>
# band.php?band_id=9085
# <artistMT.artistMTURLInfo object at 0x1a26b065f8>
# band.php?band_id=8941
# <artistMT.artistMTURLInfo object at 0x1a26b06668>
# band.php?band_id=8346
# <artistMT.artistMTURLInfo object at 0x1a26b06710>
# band.php?band_id=7646
# <artistMT.artistMTURLInfo object at 0x1a26b065f8>
# band.php?band_id=1550
# <artistMT.artistMTURLInfo object at 0x1a26b06630>
# band.php?band_id=9557
# <artistMT.artistMTURLInfo object at 0x1a26b066a0>
# band.php?band_id=10950
# <artistMT.artistMTURLInfo object at 0x1a26b06710>
# band.php?band_id=9095
# <artistMT.artistMTURLInfo object at 0x1a26b06630>
# band.php?band_id=1633
# <artistMT.artistMTURLInfo object at 0x1a26b065f8>
# band.php?band_id=6182
# <artistMT.artistMTURLInfo object at 0x1a26b06710>
# band.php?band_id=8312
# <artistMT.artistMTURLInfo object at 0x1a26b06668>
# band.php?band_id=8578
# <artistMT.artistMTURLInfo object at 0x1a26b06588>
# band.php?band_id=9703
# <artistMT.artistMTURLInfo object at 0x1a26389ac8>
# band.php?band_id=10683
# <artistMT.artistMTURLInfo object at 0x1a26b06668>
# band.php?band_id=1648
# <artistMT.artistMTURLInfo object at 0x1a26b06630>
# band.php?band_id=7570
# <artistMT.artistMTURLInfo object at 0x1a26b065f8>
# band.php?band_id=7995
# <artistMT.artistMTURLInfo object at 0x1a26b06668>
# band.php?band_id=10578
# <artistMT.artistMTURLInfo object at 0x1a26b06710>
# band.php?band_id=11457
# <artistMT.artistMTURLInfo object at 0x1a26b06630>
# band.php?band_id=8482
# <artistMT.artistMTURLInfo object at 0x1a26b06588>
# band.php?band_id=6839
# <artistMT.artistMTURLInfo object at 0x1a26b06668>
# band.php?band_id=8665
# <artistMT.artistMTURLInfo object at 0x1a26b06710>
# band.php?band_id=6888
# <artistMT.artistMTURLInfo object at 0x1a26b065f8>
# band.php?band_id=3080
# <artistMT.artistMTURLInfo object at 0x1a26b06588>
# band.php?band_id=10361
# <artistMT.artistMTURLInfo object at 0x1a26b06668>
# band.php?band_id=9036
# <artistMT.artistMTURLInfo object at 0x1a26b06630>
# band.php?band_id=7137
# <artistMT.artistMTURLInfo object at 0x1a26b065f8>
# band.php?band_id=8610
# <artistMT.artistMTURLInfo object at 0x1a26b06588>
# band.php?band_id=8036
# <artistMT.artistMTURLInfo object at 0x1a26b06710>
# band.php?band_id=10333
# <artistMT.artistMTURLInfo object at 0x1a26b06630>
# band.php?band_id=11204
# <artistMT.artistMTURLInfo object at 0x1a26b065f8>
# band.php?band_id=817
# <artistMT.artistMTURLInfo object at 0x1a26b06668>
# band.php?band_id=11533
# <artistMT.artistMTURLInfo object at 0x1a26b06710>
# band.php?band_id=10610
# <artistMT.artistMTURLInfo object at 0x1a26b066a0>
# band.php?band_id=11296
# <artistMT.artistMTURLInfo object at 0x1a26583048>
# band.php?band_id=7388
# <artistMT.artistMTURLInfo object at 0x1a26b06668>
# band.php?band_id=7406
# <artistMT.artistMTURLInfo object at 0x1a26b066a0>
# band.php?band_id=9198
# <artistMT.artistMTURLInfo object at 0x1a26b06630>
# band.php?band_id=10106
# <artistMT.artistMTURLInfo object at 0x1a26b066a0>
# band.php?band_id=8745
# <artistMT.artistMTURLInfo object at 0x1a26b06668>
# band.php?band_id=655
# <artistMT.artistMTURLInfo object at 0x1a26b06710>
# band.php?band_id=7939
# <artistMT.artistMTURLInfo object at 0x1a26b06588>
# band.php?band_id=763
# <artistMT.artistMTURLInfo object at 0x1a26b066a0>
# band.php?band_id=10124
# <artistMT.artistMTURLInfo object at 0x1a26b06668>
# band.php?band_id=9518
# <artistMT.artistMTURLInfo object at 0x1a26b06588>
# band.php?band_id=1656
# <artistMT.artistMTURLInfo object at 0x1a26b06630>
# band.php?band_id=7924
# <artistMT.artistMTURLInfo object at 0x1a26b06668>
# band.php?band_id=4349
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index104.p
# <artistMT.artistMTURLInfo object at 0x1a25c6a278>
# band.php?band_id=10102
# <artistMT.artistMTURLInfo object at 0x1a25c6a1d0>
# band.php?band_id=7576
# <artistMT.artistMTURLInfo object at 0x1a25c6a240>
# band.php?band_id=9392
# <artistMT.artistMTURLInfo object at 0x1a25c6a278>
# band.php?band_id=8776
# <artistMT.artistMTURLInfo object at 0x1a25c6a2b0>
# band.php?band_id=7285
# <artistMT.artistMTURLInfo object at 0x1a25c6a2e8>
# band.php?band_id=8867
# <artistMT.artistMTURLInfo object at 0x1a25c6a278>
# band.php?band_id=9923
# <artistMT.artistMTURLInfo object at 0x1a25c6a1d0>
# band.php?band_id=9362
# <artistMT.artistMTURLInfo object at 0x1a25c6a2e8>
# band.php?band_id=4609
# <artistMT.artistMTURLInfo object at 0x1a25c6a2b0>
# band.php?band_id=7320
# <artistMT.artistMTURLInfo object at 0x1a25c6a278>
# band.php?band_id=9973
# <artistMT.artistMTURLInfo object at 0x1a25c6a2e8>
# band.php?band_id=2739
# <artistMT.artistMTURLInfo object at 0x1a25c6a1d0>
# band.php?band_id=1768
# <artistMT.artistMTURLInfo object at 0x1a25c6a2b0>
# band.php?band_id=6951
# <artistMT.artistMTURLInfo object at 0x1a25c6a2e8>
# band.php?band_id=7445
# <artistMT.artistMTURLInfo object at 0x1a25c6a278>
# band.php?band_id=7769
# <artistMT.artistMTURLInfo object at 0x1a25c6a1d0>
# band.php?band_id=9208
# <artistMT.artistMTURLInfo object at 0x1a25c6a2b0>
# band.php?band_id=10002
# <artistMT.artistMTURLInfo object at 0x1a25c6a2e8>
# band.php?band_id=10360
# <artistMT.artistMTURLInfo object at 0x1a25c6a278>
# band.php?band_id=9045
# <artistMT.artistMTURLInfo object at 0x1a25c6a2b0>
# band.php?band_id=10234
# <artistMT.artistMTURLInfo object at 0x1a25c6a1d0>
# band.php?band_id=9216
# <artistMT.artistMTURLInfo object at 0x1a25c6a2e8>
# band.php?band_id=11350
# <artistMT.artistMTURLInfo object at 0x1a25c6a2b0>
# band.php?band_id=10506
# <artistMT.artistMTURLInfo object at 0x1a25c6a240>
# band.php?band_id=9130
# <artistMT.artistMTURLInfo object at 0x1a25c6a358>
# band.php?band_id=11235
# <artistMT.artistMTURLInfo object at 0x1a25c6a2e8>
# band.php?band_id=5978
# <artistMT.artistMTURLInfo object at 0x1a25c6a240>
# band.php?band_id=9561
# <artistMT.artistMTURLInfo object at 0x1a25c6a278>
# band.php?band_id=4637
# <artistMT.artistMTURLInfo object at 0x1a25c6a2e8>
# band.php?band_id=6465
# <artistMT.artistMTURLInfo object at 0x1a25c6a240>
# band.php?band_id=7267
# <artistMT.artistMTURLInfo object at 0x1a25c6a358>
# band.php?band_id=9034
# <artistMT.artistMTURLInfo object at 0x1a25c6a1d0>
# band.php?band_id=6916
# <artistMT.artistMTURLInfo object at 0x1a25c6a278>
# band.php?band_id=3620
# <artistMT.artistMTURLInfo object at 0x1a25c6a2b0>
# band.php?band_id=7272
# <artistMT.artistMTURLInfo object at 0x1a25c6a358>
# band.php?band_id=6302
# <artistMT.artistMTURLInfo object at 0x1a25c6a2b0>
# band.php?band_id=11354
# <artistMT.artistMTURLInfo object at 0x1a25c6a2e8>
# band.php?band_id=8646
# <artistMT.artistMTURLInfo object at 0x1a25c6a358>
# band.php?band_id=8964
# <artistMT.artistMTURLInfo object at 0x1a25c6a240>
# band.php?band_id=3139
# <artistMT.artistMTURLInfo object at 0x1a25c6a2b0>
# band.php?band_id=9124
# <artistMT.artistMTURLInfo object at 0x1a25c6a2e8>
# band.php?band_id=11162
# <artistMT.artistMTURLInfo object at 0x1a25c6a358>
# band.php?band_id=9474
# <artistMT.artistMTURLInfo object at 0x1a25c6a240>
# band.php?band_id=7878
# <artistMT.artistMTURLInfo object at 0x1a25c6a278>
# band.php?band_id=11447
# <artistMT.artistMTURLInfo object at 0x1a25c6a1d0>
# band.php?band_id=8112
# <artistMT.artistMTURLInfo object at 0x1a25c6a358>
# band.php?band_id=890
# <artistMT.artistMTURLInfo object at 0x1a25c6a240>
# band.php?band_id=3305
# <artistMT.artistMTURLInfo object at 0x1a25c6a2e8>
# band.php?band_id=10964
# <artistMT.artistMTURLInfo object at 0x1a25c6a278>
# band.php?band_id=9475
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index105.p
# <artistMT.artistMTURLInfo object at 0x1a270da7b8>
# band.php?band_id=1267
# <artistMT.artistMTURLInfo object at 0x1a270da7f0>
# band.php?band_id=7279
# <artistMT.artistMTURLInfo object at 0x1a270da780>
# band.php?band_id=9984
# <artistMT.artistMTURLInfo object at 0x1a270da7b8>
# band.php?band_id=9500
# <artistMT.artistMTURLInfo object at 0x1a270da828>
# band.php?band_id=7338
# <artistMT.artistMTURLInfo object at 0x1a270da7b8>
# band.php?band_id=5220
# <artistMT.artistMTURLInfo object at 0x1a270da7f0>
# band.php?band_id=8903
# <artistMT.artistMTURLInfo object at 0x1a270da828>
# band.php?band_id=4460
# <artistMT.artistMTURLInfo object at 0x1a270da7b8>
# band.php?band_id=9979
# <artistMT.artistMTURLInfo object at 0x1a270da7f0>
# band.php?band_id=11098
# <artistMT.artistMTURLInfo object at 0x1a270da828>
# band.php?band_id=9678
# <artistMT.artistMTURLInfo object at 0x1a270da7b8>
# band.php?band_id=845
# <artistMT.artistMTURLInfo object at 0x1a270da780>
# band.php?band_id=10467
# <artistMT.artistMTURLInfo object at 0x1a270da828>
# band.php?band_id=10784
# <artistMT.artistMTURLInfo object at 0x1a270da7f0>
# band.php?band_id=9315
# <artistMT.artistMTURLInfo object at 0x1a270da780>
# band.php?band_id=8493
# <artistMT.artistMTURLInfo object at 0x1a270da828>
# band.php?band_id=387
# <artistMT.artistMTURLInfo object at 0x1a270da7f0>
# band.php?band_id=6991
# <artistMT.artistMTURLInfo object at 0x1a270da780>
# band.php?band_id=9387
# <artistMT.artistMTURLInfo object at 0x1a270da828>
# band.php?band_id=3005
# <artistMT.artistMTURLInfo object at 0x1a270da7f0>
# band.php?band_id=11007
# <artistMT.artistMTURLInfo object at 0x1a270da780>
# band.php?band_id=7296
# <artistMT.artistMTURLInfo object at 0x1a270da828>
# band.php?band_id=634
# <artistMT.artistMTURLInfo object at 0x1a270da7b8>
# band.php?band_id=10447
# <artistMT.artistMTURLInfo object at 0x1a270da780>
# band.php?band_id=10707
# <artistMT.artistMTURLInfo object at 0x1a270da7b8>
# band.php?band_id=6713
# <artistMT.artistMTURLInfo object at 0x1a270da7f0>
# band.php?band_id=11608
# <artistMT.artistMTURLInfo object at 0x1a270da780>
# band.php?band_id=7950
# <artistMT.artistMTURLInfo object at 0x1a270da7b8>
# band.php?band_id=10377
# <artistMT.artistMTURLInfo object at 0x1a270da828>
# band.php?band_id=8456
# <artistMT.artistMTURLInfo object at 0x1a270da780>
# band.php?band_id=10934
# <artistMT.artistMTURLInfo object at 0x1a270da828>
# band.php?band_id=9129
# <artistMT.artistMTURLInfo object at 0x1a270da7b8>
# band.php?band_id=728
# <artistMT.artistMTURLInfo object at 0x1a270da780>
# band.php?band_id=8143
# <artistMT.artistMTURLInfo object at 0x1a270da7b8>
# band.php?band_id=9819
# <artistMT.artistMTURLInfo object at 0x1a270da828>
# band.php?band_id=1375
# <artistMT.artistMTURLInfo object at 0x1a270da898>
# band.php?band_id=11572
# <artistMT.artistMTURLInfo object at 0x1a270da7b8>
# band.php?band_id=8861
# <artistMT.artistMTURLInfo object at 0x1a270da898>
# band.php?band_id=9796
# <artistMT.artistMTURLInfo object at 0x1a270da828>
# band.php?band_id=8005
# <artistMT.artistMTURLInfo object at 0x1a270da898>
# band.php?band_id=5287
# <artistMT.artistMTURLInfo object at 0x1a270da7b8>
# band.php?band_id=9551
# <artistMT.artistMTURLInfo object at 0x1a270da828>
# band.php?band_id=3672
# <artistMT.artistMTURLInfo object at 0x1a270da898>
# band.php?band_id=10922
# <artistMT.artistMTURLInfo object at 0x1a270da7b8>
# band.php?band_id=9056
# <artistMT.artistMTURLInfo object at 0x1a270da828>
# band.php?band_id=6624
# <artistMT.artistMTURLInfo object at 0x1a270da898>
# band.php?band_id=5208
# <artistMT.artistMTURLInfo object at 0x1a270da7b8>
# band.php?band_id=10363
# <artistMT.artistMTURLInfo object at 0x1a270da828>
# band.php?band_id=7362
# <artistMT.artistMTURLInfo object at 0x1a270da898>
# band.php?band_id=7136
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index106.p
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=10310
# <artistMT.artistMTURLInfo object at 0x1a271426a0>
# band.php?band_id=3291
# <artistMT.artistMTURLInfo object at 0x1a25c6a278>
# band.php?band_id=8875
# <artistMT.artistMTURLInfo object at 0x1a27142748>
# band.php?band_id=8588
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=8966
# <artistMT.artistMTURLInfo object at 0x1a27142710>
# band.php?band_id=10577
# <artistMT.artistMTURLInfo object at 0x1a270da898>
# band.php?band_id=2668
# <artistMT.artistMTURLInfo object at 0x1a27142748>
# band.php?band_id=2264
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=9133
# <artistMT.artistMTURLInfo object at 0x1a27142828>
# band.php?band_id=7410
# <artistMT.artistMTURLInfo object at 0x1a27142710>
# band.php?band_id=7937
# <artistMT.artistMTURLInfo object at 0x1a271427b8>
# band.php?band_id=10638
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=8963
# <artistMT.artistMTURLInfo object at 0x1a271427b8>
# band.php?band_id=10370
# <artistMT.artistMTURLInfo object at 0x1a27142710>
# band.php?band_id=9632
# <artistMT.artistMTURLInfo object at 0x1a27142748>
# band.php?band_id=8994
# <artistMT.artistMTURLInfo object at 0x1a271426a0>
# band.php?band_id=9417
# <artistMT.artistMTURLInfo object at 0x1a271427b8>
# band.php?band_id=10132
# <artistMT.artistMTURLInfo object at 0x1a27142710>
# band.php?band_id=8817
# <artistMT.artistMTURLInfo object at 0x1a27142748>
# band.php?band_id=9969
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=11428
# <artistMT.artistMTURLInfo object at 0x1a270da898>
# band.php?band_id=9871
# <artistMT.artistMTURLInfo object at 0x1a271427b8>
# band.php?band_id=5012
# <artistMT.artistMTURLInfo object at 0x1a25c6a278>
# band.php?band_id=10593
# <artistMT.artistMTURLInfo object at 0x1a27142828>
# band.php?band_id=7738
# <artistMT.artistMTURLInfo object at 0x1a271427b8>
# band.php?band_id=10392
# <artistMT.artistMTURLInfo object at 0x1a27142710>
# band.php?band_id=8545
# <artistMT.artistMTURLInfo object at 0x1a27142748>
# band.php?band_id=8008
# <artistMT.artistMTURLInfo object at 0x1a271426a0>
# band.php?band_id=9350
# <artistMT.artistMTURLInfo object at 0x1a271427b8>
# band.php?band_id=673
# <artistMT.artistMTURLInfo object at 0x1a27142710>
# band.php?band_id=8975
# <artistMT.artistMTURLInfo object at 0x1a27142748>
# band.php?band_id=8900
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=10367
# <artistMT.artistMTURLInfo object at 0x1a271426a0>
# band.php?band_id=2151
# <artistMT.artistMTURLInfo object at 0x1a27142710>
# band.php?band_id=11284
# <artistMT.artistMTURLInfo object at 0x1a27142748>
# band.php?band_id=1439
# <artistMT.artistMTURLInfo object at 0x1a27142828>
# band.php?band_id=2113
# <artistMT.artistMTURLInfo object at 0x1a271426a0>
# band.php?band_id=7106
# <artistMT.artistMTURLInfo object at 0x1a27142828>
# band.php?band_id=11282
# <artistMT.artistMTURLInfo object at 0x1a27142748>
# band.php?band_id=2355
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=7193
# <artistMT.artistMTURLInfo object at 0x1a270da898>
# band.php?band_id=10481
# <artistMT.artistMTURLInfo object at 0x1a271426a0>
# band.php?band_id=8192
# <artistMT.artistMTURLInfo object at 0x1a27142748>
# band.php?band_id=9930
# <artistMT.artistMTURLInfo object at 0x1a271427b8>
# band.php?band_id=9401
# <artistMT.artistMTURLInfo object at 0x1a271426a0>
# band.php?band_id=9951
# <artistMT.artistMTURLInfo object at 0x1a27142828>
# band.php?band_id=10034
# <artistMT.artistMTURLInfo object at 0x1a27142748>
# band.php?band_id=6617
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=7799
# <artistMT.artistMTURLInfo object at 0x1a271426a0>
# band.php?band_id=11506
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index107.p
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=11461
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=2433
# <artistMT.artistMTURLInfo object at 0x1a26fa9630>
# band.php?band_id=3086
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=10004
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=3438
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=9821
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=11451
# <artistMT.artistMTURLInfo object at 0x1a26fa95c0>
# band.php?band_id=1458
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=10398
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=7940
# <artistMT.artistMTURLInfo object at 0x1a26fa9630>
# band.php?band_id=7161
# <artistMT.artistMTURLInfo object at 0x1a26fa95c0>
# band.php?band_id=9560
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=9903
# <artistMT.artistMTURLInfo object at 0x1a25c6af60>
# band.php?band_id=9718
# <artistMT.artistMTURLInfo object at 0x1a26fa9630>
# band.php?band_id=1235
# <artistMT.artistMTURLInfo object at 0x1a26fa95c0>
# band.php?band_id=11046
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=7680
# <artistMT.artistMTURLInfo object at 0x1a25c6af60>
# band.php?band_id=9409
# <artistMT.artistMTURLInfo object at 0x1a26fa9630>
# band.php?band_id=8012
# <artistMT.artistMTURLInfo object at 0x1a26fa95c0>
# band.php?band_id=9303
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=10078
# <artistMT.artistMTURLInfo object at 0x1a25c6af60>
# band.php?band_id=8158
# <artistMT.artistMTURLInfo object at 0x1a26fa9630>
# band.php?band_id=8230
# <artistMT.artistMTURLInfo object at 0x1a26fa95c0>
# band.php?band_id=10025
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=6279
# <artistMT.artistMTURLInfo object at 0x1a271426a0>
# band.php?band_id=1160
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=8607
# <artistMT.artistMTURLInfo object at 0x1a26fa95c0>
# band.php?band_id=4535
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=9433
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=1127
# <artistMT.artistMTURLInfo object at 0x1a26fa9630>
# band.php?band_id=7633
# <artistMT.artistMTURLInfo object at 0x1a26fa95c0>
# band.php?band_id=5849
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=4834
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=9122
# <artistMT.artistMTURLInfo object at 0x1a26fa9630>
# band.php?band_id=7693
# <artistMT.artistMTURLInfo object at 0x1a26fa95c0>
# band.php?band_id=10974
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=6167
# <artistMT.artistMTURLInfo object at 0x1a25c6af60>
# band.php?band_id=10539
# <artistMT.artistMTURLInfo object at 0x1a26fa9630>
# band.php?band_id=10030
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=10269
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=9548
# <artistMT.artistMTURLInfo object at 0x1a27142780>
# band.php?band_id=10441
# <artistMT.artistMTURLInfo object at 0x1a26fa9630>
# band.php?band_id=8423
# <artistMT.artistMTURLInfo object at 0x1a26fa95c0>
# band.php?band_id=4567
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=736
# <artistMT.artistMTURLInfo object at 0x1a25c6af60>
# band.php?band_id=9455
# <artistMT.artistMTURLInfo object at 0x1a26fa9630>
# band.php?band_id=9058
# <artistMT.artistMTURLInfo object at 0x1a26fa95c0>
# band.php?band_id=3994
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=9375
# <artistMT.artistMTURLInfo object at 0x1a25c6af60>
# band.php?band_id=8746
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index108.p
# <artistMT.artistMTURLInfo object at 0x1a25ba8a20>
# band.php?band_id=9442
# <artistMT.artistMTURLInfo object at 0x1a25ba8ac8>
# band.php?band_id=10627
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=9503
# <artistMT.artistMTURLInfo object at 0x1a25c6af60>
# band.php?band_id=686
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=9576
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=10421
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=9096
# <artistMT.artistMTURLInfo object at 0x1a25c6af60>
# band.php?band_id=2862
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=4083
# <artistMT.artistMTURLInfo object at 0x1a25ba8ac8>
# band.php?band_id=10916
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=1689
# <artistMT.artistMTURLInfo object at 0x1a25c6af60>
# band.php?band_id=8260
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=9709
# <artistMT.artistMTURLInfo object at 0x1a25ba8ac8>
# band.php?band_id=9388
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=9328
# <artistMT.artistMTURLInfo object at 0x1a25c6af60>
# band.php?band_id=2299
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=470
# <artistMT.artistMTURLInfo object at 0x1a25ba8ac8>
# band.php?band_id=9079
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=6920
# <artistMT.artistMTURLInfo object at 0x1a25c6af60>
# band.php?band_id=7790
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=4736
# <artistMT.artistMTURLInfo object at 0x1a25ba8ac8>
# band.php?band_id=8949
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=8526
# <artistMT.artistMTURLInfo object at 0x1a25c6af60>
# band.php?band_id=9711
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=9435
# <artistMT.artistMTURLInfo object at 0x1a25ba8ac8>
# band.php?band_id=9158
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=11494
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=8214
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=7392
# <artistMT.artistMTURLInfo object at 0x1a25ba8ac8>
# band.php?band_id=10639
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=9422
# <artistMT.artistMTURLInfo object at 0x1a26fa9630>
# band.php?band_id=2831
# <artistMT.artistMTURLInfo object at 0x1a25ba8940>
# band.php?band_id=9039
# <artistMT.artistMTURLInfo object at 0x1a25ba89e8>
# band.php?band_id=6202
# <artistMT.artistMTURLInfo object at 0x1a25ba8a58>
# band.php?band_id=3174
# <artistMT.artistMTURLInfo object at 0x1a25ba8940>
# band.php?band_id=9654
# <artistMT.artistMTURLInfo object at 0x1a25ba89e8>
# band.php?band_id=9580
# <artistMT.artistMTURLInfo object at 0x1a25ba8940>
# band.php?band_id=1357
# <artistMT.artistMTURLInfo object at 0x1a25ba89e8>
# band.php?band_id=5974
# <artistMT.artistMTURLInfo object at 0x1a25ba8940>
# band.php?band_id=9260
# <artistMT.artistMTURLInfo object at 0x1a25ba89e8>
# band.php?band_id=6513
# <artistMT.artistMTURLInfo object at 0x1a25ba8940>
# band.php?band_id=6149
# <artistMT.artistMTURLInfo object at 0x1a25ba8ac8>
# band.php?band_id=8735
# <artistMT.artistMTURLInfo object at 0x1a25ba89b0>
# band.php?band_id=9642
# <artistMT.artistMTURLInfo object at 0x1a26fa9630>
# band.php?band_id=9574
# <artistMT.artistMTURLInfo object at 0x1a26fa9588>
# band.php?band_id=10148
# <artistMT.artistMTURLInfo object at 0x1a25ba89e8>
# band.php?band_id=2672
# <artistMT.artistMTURLInfo object at 0x1a25ba89b0>
# band.php?band_id=1254
# <artistMT.artistMTURLInfo object at 0x1a25ba8ac8>
# band.php?band_id=5192
# <artistMT.artistMTURLInfo object at 0x1a25c6af60>
# band.php?band_id=9117
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index109.p
# <artistMT.artistMTURLInfo object at 0x1a26afba58>
# band.php?band_id=10419
# <artistMT.artistMTURLInfo object at 0x1a26afb9e8>
# band.php?band_id=7980
# <artistMT.artistMTURLInfo object at 0x1a26afbb00>
# band.php?band_id=4444
# <artistMT.artistMTURLInfo object at 0x1a26afba20>
# band.php?band_id=9145
# <artistMT.artistMTURLInfo object at 0x1a26afba58>
# band.php?band_id=1382
# <artistMT.artistMTURLInfo object at 0x1a26afba90>
# band.php?band_id=412
# <artistMT.artistMTURLInfo object at 0x1a26afbb00>
# band.php?band_id=9640
# <artistMT.artistMTURLInfo object at 0x1a26afb978>
# band.php?band_id=5097
# <artistMT.artistMTURLInfo object at 0x1a26afba58>
# band.php?band_id=8978
# <artistMT.artistMTURLInfo object at 0x1a26afbb00>
# band.php?band_id=2097
# <artistMT.artistMTURLInfo object at 0x1a26afba90>
# band.php?band_id=10212
# <artistMT.artistMTURLInfo object at 0x1a26afb9e8>
# band.php?band_id=325
# <artistMT.artistMTURLInfo object at 0x1a26afba90>
# band.php?band_id=10180
# <artistMT.artistMTURLInfo object at 0x1a26afb978>
# band.php?band_id=7959
# <artistMT.artistMTURLInfo object at 0x1a26afb9e8>
# band.php?band_id=8729
# <artistMT.artistMTURLInfo object at 0x1a26afba20>
# band.php?band_id=8690
# <artistMT.artistMTURLInfo object at 0x1a26afba90>
# band.php?band_id=3348
# <artistMT.artistMTURLInfo object at 0x1a26afb9e8>
# band.php?band_id=10349
# <artistMT.artistMTURLInfo object at 0x1a26afb978>
# band.php?band_id=11047
# <artistMT.artistMTURLInfo object at 0x1a26afbb00>
# band.php?band_id=10566
# <artistMT.artistMTURLInfo object at 0x1a26afba58>
# band.php?band_id=9628
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=9338
# <artistMT.artistMTURLInfo object at 0x1a26afb978>
# band.php?band_id=8740
# <artistMT.artistMTURLInfo object at 0x1a26afba20>
# band.php?band_id=8004
# <artistMT.artistMTURLInfo object at 0x1a26afbb00>
# band.php?band_id=1314
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=625
# <artistMT.artistMTURLInfo object at 0x1a26afb978>
# band.php?band_id=5532
# <artistMT.artistMTURLInfo object at 0x1a26afba90>
# band.php?band_id=1041
# <artistMT.artistMTURLInfo object at 0x1a26afb9e8>
# band.php?band_id=9911
# <artistMT.artistMTURLInfo object at 0x1a26afba58>
# band.php?band_id=4287
# <artistMT.artistMTURLInfo object at 0x1a26afb978>
# band.php?band_id=7308
# <artistMT.artistMTURLInfo object at 0x1a26afbb00>
# band.php?band_id=974
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=9427
# <artistMT.artistMTURLInfo object at 0x1a26afba58>
# band.php?band_id=10765
# <artistMT.artistMTURLInfo object at 0x1a26afb978>
# band.php?band_id=8833
# <artistMT.artistMTURLInfo object at 0x1a26afba20>
# band.php?band_id=11314
# <artistMT.artistMTURLInfo object at 0x1a26afba90>
# band.php?band_id=6889
# <artistMT.artistMTURLInfo object at 0x1a26afba58>
# band.php?band_id=11115
# <artistMT.artistMTURLInfo object at 0x1a26afb9e8>
# band.php?band_id=6939
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=9046
# <artistMT.artistMTURLInfo object at 0x1a26afba90>
# band.php?band_id=6265
# <artistMT.artistMTURLInfo object at 0x1a26afba58>
# band.php?band_id=9604
# <artistMT.artistMTURLInfo object at 0x1a26afb978>
# band.php?band_id=8249
# <artistMT.artistMTURLInfo object at 0x1a26afb9e8>
# band.php?band_id=11479
# <artistMT.artistMTURLInfo object at 0x1a26afba90>
# band.php?band_id=7467
# <artistMT.artistMTURLInfo object at 0x1a26afba58>
# band.php?band_id=1159
# <artistMT.artistMTURLInfo object at 0x1a26afbb00>
# band.php?band_id=7486
# <artistMT.artistMTURLInfo object at 0x1a26afb9e8>
# band.php?band_id=10446
# <artistMT.artistMTURLInfo object at 0x1a26afba90>
# band.php?band_id=10045
# <artistMT.artistMTURLInfo object at 0x1a26afb978>
# band.php?band_id=9254
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index11.p
# <artistMT.artistMTURLInfo object at 0x1a2657a400>
# band.php?band_id=3194
# <artistMT.artistMTURLInfo object at 0x1a2657a4e0>
# band.php?band_id=2597
# <artistMT.artistMTURLInfo object at 0x1a2657a3c8>
# band.php?band_id=418
# <artistMT.artistMTURLInfo object at 0x1a26afb978>
# band.php?band_id=27
# <artistMT.artistMTURLInfo object at 0x1a2657a438>
# band.php?band_id=2662
# <artistMT.artistMTURLInfo object at 0x1a2657a4e0>
# band.php?band_id=7414
# <artistMT.artistMTURLInfo object at 0x1a2657a358>
# band.php?band_id=3253
# <artistMT.artistMTURLInfo object at 0x1a2657a3c8>
# band.php?band_id=362
# <artistMT.artistMTURLInfo object at 0x1a2657a438>
# band.php?band_id=1995
# <artistMT.artistMTURLInfo object at 0x1a2657a4e0>
# band.php?band_id=3447
# <artistMT.artistMTURLInfo object at 0x1a2657a470>
# band.php?band_id=554
# <artistMT.artistMTURLInfo object at 0x1a2657a400>
# band.php?band_id=3668
# <artistMT.artistMTURLInfo object at 0x1a2657a438>
# band.php?band_id=2647
# <artistMT.artistMTURLInfo object at 0x1a2657a4e0>
# band.php?band_id=5130
# <artistMT.artistMTURLInfo object at 0x1a2657a358>
# band.php?band_id=6248
# <artistMT.artistMTURLInfo object at 0x1a2657a3c8>
# band.php?band_id=353
# <artistMT.artistMTURLInfo object at 0x1a2657a438>
# band.php?band_id=17
# <artistMT.artistMTURLInfo object at 0x1a2657a400>
# band.php?band_id=323
# <artistMT.artistMTURLInfo object at 0x1a2657a470>
# band.php?band_id=3990
# <artistMT.artistMTURLInfo object at 0x1a2657a358>
# band.php?band_id=1099
# <artistMT.artistMTURLInfo object at 0x1a26afb978>
# band.php?band_id=667
# <artistMT.artistMTURLInfo object at 0x1a2657a400>
# band.php?band_id=2942
# <artistMT.artistMTURLInfo object at 0x1a2657a470>
# band.php?band_id=7201
# <artistMT.artistMTURLInfo object at 0x1a2657a358>
# band.php?band_id=756
# <artistMT.artistMTURLInfo object at 0x1a2657a438>
# band.php?band_id=103
# <artistMT.artistMTURLInfo object at 0x1a2657a4e0>
# band.php?band_id=523
# <artistMT.artistMTURLInfo object at 0x1a2657a470>
# band.php?band_id=587
# <artistMT.artistMTURLInfo object at 0x1a2657a3c8>
# band.php?band_id=541
# <artistMT.artistMTURLInfo object at 0x1a2657a358>
# band.php?band_id=5
# <artistMT.artistMTURLInfo object at 0x1a2657a4e0>
# band.php?band_id=5369
# <artistMT.artistMTURLInfo object at 0x1a2657a438>
# band.php?band_id=3187
# <artistMT.artistMTURLInfo object at 0x1a2657a3c8>
# band.php?band_id=461
# <artistMT.artistMTURLInfo object at 0x1a2657a358>
# band.php?band_id=48
# <artistMT.artistMTURLInfo object at 0x1a2657a4e0>
# band.php?band_id=3925
# <artistMT.artistMTURLInfo object at 0x1a2657a438>
# band.php?band_id=10137
# <artistMT.artistMTURLInfo object at 0x1a2657a3c8>
# band.php?band_id=3001
# <artistMT.artistMTURLInfo object at 0x1a2657a400>
# band.php?band_id=407
# <artistMT.artistMTURLInfo object at 0x1a2657a4e0>
# band.php?band_id=2177
# <artistMT.artistMTURLInfo object at 0x1a2657a438>
# band.php?band_id=2887
# <artistMT.artistMTURLInfo object at 0x1a2657a3c8>
# band.php?band_id=2996
# <artistMT.artistMTURLInfo object at 0x1a2657a470>
# band.php?band_id=170
# <artistMT.artistMTURLInfo object at 0x1a26fa9550>
# band.php?band_id=2500
# <artistMT.artistMTURLInfo object at 0x1a2657a438>
# band.php?band_id=6481
# <artistMT.artistMTURLInfo object at 0x1a2657a4e0>
# band.php?band_id=3773
# <artistMT.artistMTURLInfo object at 0x1a26afb978>
# band.php?band_id=4410
# <artistMT.artistMTURLInfo object at 0x1a2657a400>
# band.php?band_id=9312
# <artistMT.artistMTURLInfo object at 0x1a2657a438>
# band.php?band_id=409
# <artistMT.artistMTURLInfo object at 0x1a2657a3c8>
# band.php?band_id=108
# <artistMT.artistMTURLInfo object at 0x1a2657a4e0>
# band.php?band_id=190
# <artistMT.artistMTURLInfo object at 0x1a2657a400>
# band.php?band_id=589
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index110.p
# <artistMT.artistMTURLInfo object at 0x1a261834a8>
# band.php?band_id=10162
# <artistMT.artistMTURLInfo object at 0x1a2657a4e0>
# band.php?band_id=8980
# <artistMT.artistMTURLInfo object at 0x1a26183588>
# band.php?band_id=6800
# ...
# Saving /Volumes/Biggy/Discog/artists-metalstorm/57/8757.p (force=False)
#   --> This file is 14.4kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f588>
# band.php?band_id=279
# Saving /Volumes/Biggy/Discog/artists-metalstorm/79/279.p (force=False)
#   --> This file is 13.3kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25b2c080>
# band.php?band_id=96
# Saving /Volumes/Biggy/Discog/artists-metalstorm/96/96.p (force=False)
#   --> This file is 13.8kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f668>
# band.php?band_id=268
# Saving /Volumes/Biggy/Discog/artists-metalstorm/68/268.p (force=False)
#   --> This file is 15.2kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f748>
# band.php?band_id=4713
# Saving /Volumes/Biggy/Discog/artists-metalstorm/13/4713.p (force=False)
#   --> This file is 13.2kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a27142898>
# band.php?band_id=551
# Saving /Volumes/Biggy/Discog/artists-metalstorm/51/551.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f588>
# band.php?band_id=365
# Saving /Volumes/Biggy/Discog/artists-metalstorm/65/365.p (force=False)
#   --> This file is 12.4kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f668>
# band.php?band_id=271
# Saving /Volumes/Biggy/Discog/artists-metalstorm/71/271.p (force=False)
#   --> This file is 13.8kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f748>
# band.php?band_id=2076
# Saving /Volumes/Biggy/Discog/artists-metalstorm/76/2076.p (force=False)
#   --> This file is 13.3kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25b2c5f8>
# band.php?band_id=2494
# Saving /Volumes/Biggy/Discog/artists-metalstorm/94/2494.p (force=False)
#   --> This file is 13.4kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25b2c080>
# band.php?band_id=6675
# Saving /Volumes/Biggy/Discog/artists-metalstorm/75/6675.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f668>
# band.php?band_id=2848
# Saving /Volumes/Biggy/Discog/artists-metalstorm/48/2848.p (force=False)
#   --> This file is 13.0kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f748>
# band.php?band_id=1699
# Saving /Volumes/Biggy/Discog/artists-metalstorm/99/1699.p (force=False)
#   --> This file is 15.0kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25b2c080>
# band.php?band_id=573
# Saving /Volumes/Biggy/Discog/artists-metalstorm/73/573.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f588>
# band.php?band_id=4861
# Saving /Volumes/Biggy/Discog/artists-metalstorm/61/4861.p (force=False)
#   --> This file is 12.6kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f668>
# band.php?band_id=3492
# Saving /Volumes/Biggy/Discog/artists-metalstorm/92/3492.p (force=False)
#   --> This file is 13.5kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f748>
# band.php?band_id=2807
# Saving /Volumes/Biggy/Discog/artists-metalstorm/7/2807.p (force=False)
#   --> This file is 12.9kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a27142898>
# band.php?band_id=9785
# Saving /Volumes/Biggy/Discog/artists-metalstorm/85/9785.p (force=False)
#   --> This file is 12.5kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f588>
# band.php?band_id=24
# Saving /Volumes/Biggy/Discog/artists-metalstorm/24/24.p (force=False)
#   --> This file is 12.3kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f668>
# band.php?band_id=5933
# Saving /Volumes/Biggy/Discog/artists-metalstorm/33/5933.p (force=False)
#   --> This file is 14.3kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f748>
# band.php?band_id=2659
# Saving /Volumes/Biggy/Discog/artists-metalstorm/59/2659.p (force=False)
#   --> This file is 12.7kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25b2c080>
# band.php?band_id=1293
# Saving /Volumes/Biggy/Discog/artists-metalstorm/93/1293.p (force=False)
#   --> This file is 13.7kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f588>
# band.php?band_id=2176
# Saving /Volumes/Biggy/Discog/artists-metalstorm/76/2176.p (force=False)
#   --> This file is 14.8kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f668>
# band.php?band_id=252
# Saving /Volumes/Biggy/Discog/artists-metalstorm/52/252.p (force=False)
#   --> This file is 14.1kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f748>
# band.php?band_id=6327
# Saving /Volumes/Biggy/Discog/artists-metalstorm/27/6327.p (force=False)
#   --> This file is 13.0kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a27142898>
# band.php?band_id=30
# Saving /Volumes/Biggy/Discog/artists-metalstorm/30/30.p (force=False)
#   --> This file is 13.3kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f6d8>
# band.php?band_id=2526
# Saving /Volumes/Biggy/Discog/artists-metalstorm/26/2526.p (force=False)
#   --> This file is 13.0kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25b2c080>
# band.php?band_id=81
# Saving /Volumes/Biggy/Discog/artists-metalstorm/81/81.p (force=False)
#   --> This file is 13.9kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f748>
# band.php?band_id=260
# Saving /Volumes/Biggy/Discog/artists-metalstorm/60/260.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a27142898>
# band.php?band_id=7509
# Saving /Volumes/Biggy/Discog/artists-metalstorm/9/7509.p (force=False)
#   --> This file is 12.6kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f588>
# band.php?band_id=4202
# Saving /Volumes/Biggy/Discog/artists-metalstorm/2/4202.p (force=False)
#   --> This file is 12.8kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f668>
# band.php?band_id=3044
# Saving /Volumes/Biggy/Discog/artists-metalstorm/44/3044.p (force=False)
#   --> This file is 13.1kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f748>
# band.php?band_id=1605
# Saving /Volumes/Biggy/Discog/artists-metalstorm/5/1605.p (force=False)
#   --> This file is 12.6kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a27142898>
# band.php?band_id=64
# Saving /Volumes/Biggy/Discog/artists-metalstorm/64/64.p (force=False)
#   --> This file is 14.3kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25b2c080>
# band.php?band_id=469
# Saving /Volumes/Biggy/Discog/artists-metalstorm/69/469.p (force=False)
#   --> This file is 16.0kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f668>
# band.php?band_id=2645
# Saving /Volumes/Biggy/Discog/artists-metalstorm/45/2645.p (force=False)
#   --> This file is 13.1kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f748>
# band.php?band_id=2061
# Saving /Volumes/Biggy/Discog/artists-metalstorm/61/2061.p (force=False)
#   --> This file is 13.3kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a27142898>
# band.php?band_id=3792
# Saving /Volumes/Biggy/Discog/artists-metalstorm/92/3792.p (force=False)
#   --> This file is 14.3kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f588>
# band.php?band_id=4467
# Saving /Volumes/Biggy/Discog/artists-metalstorm/67/4467.p (force=False)
#   --> This file is 16.1kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f668>
# band.php?band_id=411
# Saving /Volumes/Biggy/Discog/artists-metalstorm/11/411.p (force=False)
#   --> This file is 15.5kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f748>
# band.php?band_id=238
# Saving /Volumes/Biggy/Discog/artists-metalstorm/38/238.p (force=False)
#   --> This file is 13.6kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a27142898>
# band.php?band_id=4294
# Saving /Volumes/Biggy/Discog/artists-metalstorm/94/4294.p (force=False)
#   --> This file is 14.0kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25b2c080>
# band.php?band_id=404
# Saving /Volumes/Biggy/Discog/artists-metalstorm/4/404.p (force=False)
#   --> This file is 13.5kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f668>
# band.php?band_id=2904
# Saving /Volumes/Biggy/Discog/artists-metalstorm/4/2904.p (force=False)
#   --> This file is 12.7kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25b2c080>
# band.php?band_id=4106
# Saving /Volumes/Biggy/Discog/artists-metalstorm/6/4106.p (force=False)
#   --> This file is 12.7kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a27142898>
# band.php?band_id=6978
# Saving /Volumes/Biggy/Discog/artists-metalstorm/78/6978.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f588>
# band.php?band_id=4586
# Saving /Volumes/Biggy/Discog/artists-metalstorm/86/4586.p (force=False)
#   --> This file is 13.5kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25e6f668>
# band.php?band_id=3779
# Saving /Volumes/Biggy/Discog/artists-metalstorm/79/3779.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25b2c080>
# band.php?band_id=1149
# Saving /Volumes/Biggy/Discog/artists-metalstorm/49/1149.p (force=False)
#   --> This file is 13.8kB.
# Done. Sleeping for 5 seconds
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index17.p
# <artistMT.artistMTURLInfo object at 0x1a25a94e10>
# band.php?band_id=386
# Saving /Volumes/Biggy/Discog/artists-metalstorm/86/386.p (force=False)
#   --> This file is 18.3kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94eb8>
# band.php?band_id=2782
# Saving /Volumes/Biggy/Discog/artists-metalstorm/82/2782.p (force=False)
#   --> This file is 13.8kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94e48>
# band.php?band_id=7316
# Saving /Volumes/Biggy/Discog/artists-metalstorm/16/7316.p (force=False)
#   --> This file is 12.9kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94da0>
# band.php?band_id=4811
# Saving /Volumes/Biggy/Discog/artists-metalstorm/11/4811.p (force=False)
#   --> This file is 14.2kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94eb8>
# band.php?band_id=3597
# Saving /Volumes/Biggy/Discog/artists-metalstorm/97/3597.p (force=False)
#   --> This file is 12.6kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94da0>
# band.php?band_id=10197
# Saving /Volumes/Biggy/Discog/artists-metalstorm/97/10197.p (force=False)
#   --> This file is 13.0kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94e10>
# band.php?band_id=3524
# Saving /Volumes/Biggy/Discog/artists-metalstorm/24/3524.p (force=False)
#   --> This file is 12.3kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94e48>
# band.php?band_id=2117
# Saving /Volumes/Biggy/Discog/artists-metalstorm/17/2117.p (force=False)
#   --> This file is 13.2kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94e10>
# band.php?band_id=207
# Saving /Volumes/Biggy/Discog/artists-metalstorm/7/207.p (force=False)
#   --> This file is 12.8kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94d30>
# band.php?band_id=1305
# Saving /Volumes/Biggy/Discog/artists-metalstorm/5/1305.p (force=False)
#   --> This file is 14.2kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94e48>
# band.php?band_id=2709
# Saving /Volumes/Biggy/Discog/artists-metalstorm/9/2709.p (force=False)
#   --> This file is 13.9kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94e10>
# band.php?band_id=9729
# Saving /Volumes/Biggy/Discog/artists-metalstorm/29/9729.p (force=False)
#   --> This file is 12.8kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94e48>
# band.php?band_id=2731
# Saving /Volumes/Biggy/Discog/artists-metalstorm/31/2731.p (force=False)
#   --> This file is 12.8kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94eb8>
# band.php?band_id=29
# Saving /Volumes/Biggy/Discog/artists-metalstorm/29/29.p (force=False)
#   --> This file is 14.4kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94da0>
# band.php?band_id=6557
# Saving /Volumes/Biggy/Discog/artists-metalstorm/57/6557.p (force=False)
#   --> This file is 13.4kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94e10>
# band.php?band_id=937
# Saving /Volumes/Biggy/Discog/artists-metalstorm/37/937.p (force=False)
#   --> This file is 12.9kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94e48>
# band.php?band_id=2406
# Saving /Volumes/Biggy/Discog/artists-metalstorm/6/2406.p (force=False)
#   --> This file is 19.3kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94da0>
# band.php?band_id=484
# Saving /Volumes/Biggy/Discog/artists-metalstorm/84/484.p (force=False)
#   --> This file is 16.3kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94e48>
# band.php?band_id=659
# Saving /Volumes/Biggy/Discog/artists-metalstorm/59/659.p (force=False)
#   --> This file is 13.5kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94dd8>
# band.php?band_id=3340
# Saving /Volumes/Biggy/Discog/artists-metalstorm/40/3340.p (force=False)
#   --> This file is 14.0kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94e48>
# band.php?band_id=796
# Saving /Volumes/Biggy/Discog/artists-metalstorm/96/796.p (force=False)
#   --> This file is 13.6kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94d30>
# band.php?band_id=1242
# Saving /Volumes/Biggy/Discog/artists-metalstorm/42/1242.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94e10>
# band.php?band_id=2665
# Saving /Volumes/Biggy/Discog/artists-metalstorm/65/2665.p (force=False)
#   --> This file is 12.8kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94e48>
# band.php?band_id=3711
# Saving /Volumes/Biggy/Discog/artists-metalstorm/11/3711.p (force=False)
#   --> This file is 14.0kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94d30>
# band.php?band_id=2729
# Saving /Volumes/Biggy/Discog/artists-metalstorm/29/2729.p (force=False)
#   --> This file is 14.2kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94e48>
# band.php?band_id=6196
# Saving /Volumes/Biggy/Discog/artists-metalstorm/96/6196.p (force=False)
#   --> This file is 13.4kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94dd8>
# band.php?band_id=1720
# Saving /Volumes/Biggy/Discog/artists-metalstorm/20/1720.p (force=False)
#   --> This file is 16.2kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94eb8>
# band.php?band_id=4993
# Saving /Volumes/Biggy/Discog/artists-metalstorm/93/4993.p (force=False)
#   --> This file is 13.5kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94d30>
# band.php?band_id=2259
# Saving /Volumes/Biggy/Discog/artists-metalstorm/59/2259.p (force=False)
#   --> This file is 14.5kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94da0>
# band.php?band_id=7839
# Saving /Volumes/Biggy/Discog/artists-metalstorm/39/7839.p (force=False)
#   --> This file is 13.5kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94dd8>
# band.php?band_id=4197
# Saving /Volumes/Biggy/Discog/artists-metalstorm/97/4197.p (force=False)
#   --> This file is 13.5kB.
# Done. Sleeping for 5 seconds
# <artistMT.artistMTURLInfo object at 0x1a25a94eb8>
# band.php?band_id=2023

# %%
# Out:
# <__main__.artistMTURLInfo object at 0x1a25e164e0>
# band.php?band_id=60
# 60 http://www.metalstorm.net/bands/discography.php?band_id=60
# Downloading Artist Data for ID [60]
# http://www.metalstorm.net/bands/discography.php?band_id=60
# /Volumes/Biggy/Discog/artists-metalstorm/60/60.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/60/60.p (force=False)
#   --> This file is 18.0kB.
# Done. Sleeping for 2 seconds
# Done with download artist URL
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-70-e9ca4e318a83> in <module>
#      19             print(artistID,url)
#      20             artsMT.downloadArtistFromID(artistID)
# ---> 21             1/0
#      22
#      23         else:
#
# ZeroDivisionError: division by zero

# %%
print(retval.artist.get())
print(retval.url.get())
print(retval.ID.get())
print(retval.mediaCounts.get())
for mediaType,mediaData in retval.media.media.items():
    print(mediaType)
    for media in mediaData:
        print("\t",media.get())

# %%
retval = artCL.getData("/Volumes/Biggy/Discog/artists-cdandlp/65/63161947632565.p")

# %%
url="https://listen.tidal.com/artist/3565368"
savename="tidal.p"
artsMS.downloadArtistURL(url, savename)

# %%
bsdata = getFile("tidal.p")

# %%
bsdata

# %%
retval.artist.get()

# %%
dutils.getArtistID("https://www.cdandlp.com/en/a-flock-of-seagulls/artist/")

# %%
retval.url.get()

# %%
retval.ID.get()

# %%
retval.pages.get()

# %%
for k,v in retval.media.media.items():
    for v2 in v:
        print(v2.get())
