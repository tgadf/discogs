# %% [markdown]
# # MetalStorm

# %%
######################################################
# Juypter
######################################################
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))


######################################################
# General
######################################################
from ioUtils import saveJoblib, loadJoblib, saveFile, getFile
import urllib
from urllib.parse import quote
from collection import collections
from artist import artist
from timeUtils import clock, elapsed
from fsUtils import moveFile, setFile, setDir, setSubDir, isFile, isDir, mkDir
from ioUtils import getFile, saveFile
from fileUtils import getFileBasics, getBasename
from webUtils import getWebData, getHTML, getURL
from time import sleep
import time
from multiprocessing import Pool


######################################################
# Music Stuff
######################################################
from discogsBase import discogs
from artistMT import artistMT
from artistsMT import artistsMT
from discogsUtils import metalstormUtils
from multiArtist import multiartist
from myMusicDBMap import myMusicDBMap


######################################################
# Versions
######################################################
import sys
print("Python: {0}".format(sys.version))
import datetime as dt
start = dt.datetime.now()
print("Notebook Last Run Initiated: "+str(start))

# %% [markdown]
# # Initialize

# %%
# %load_ext autoreload
# %autoreload
discMT = discogs('metalstorm')
dutils = metalstormUtils()
#artMS  = artistMS()
#artsMS = artistsMS(discMS)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # My Music

# %%
mdb = myMusicDBMap(debug=True)

# %% [markdown]
# # Search

# %%
from ioUtils import getFile, saveFile
from searchUtils import findPatternExt
from fileUtils import getBaseFilename

artMS = artistMS()
files = findPatternExt("/Users/tgadfort/Downloads/", pattern="MusicStack", ext=".html")
for ifile in files:
    fname  = getBaseFilename(ifile)
    artist = fname[:fname.find(" Vinyl Records")]
    artsMS.searchMusicStackForArtist(artist=artist, data=ifile, debug=False)

# %% [markdown]
# # Download All Music

# %%
def downloadMusicStackArtists(minI=-1):
    artists = mdb.getArtists()
    for i,artistName in enumerate(artists):
        if i <= minI:
            continue
        print("====>",i,"/",len(artists),"  : ",artistName)
        artsMS.searchMusicStackForArtist(artistName, sleeptime=15)
        break

# %%
downloadMusicStackArtists(0)

# %%
for i,searchTerm in enumerate(searchTerms):
    print("\n=====>",i,"/",len(searchTerms),"==>",searchTerm)
    artsMS.searchRateYouDPusicForArtist(searchTerm)
    known.append(searchTerm)
    sleep(3)

# %% [markdown]
# # Initialize

# %%
# %load_ext autoreload
# %autoreload
discMS = discogs('musicstack')
dutils = cdandlpUtils()
artMS  = artistMS()
artsMS = artistsMS(discMS)

# %% [markdown]
# # Music DB

# %%
mdb = myMusicDBMap(debug=True)

# %% [markdown]
# # Search

# %%
#artsCL.searchCDandLPForArtist("Anal Cunt", data=data)

# %% [markdown]
# # Download All Music

# %%
def downloadCDandLPArtists(minI=-1):
    artists = mdb.getArtists()
    for i,artistName in enumerate(artists):
        if i <= minI:
            continue
        print("====>",i,"/",len(artists),"  : ",artistName)
        artsCL.searchCDandLPForArtist(artistName, sleeptime=15)

# %%
downloadCDandLPArtists(1)

# %%
#data = getFile("Search A Flock Of Seagulls on CDandLP.html")
url="http://www.metalstorm.net/bands/discography.php?band_id=10281&bandname=Crawl"
savename="metalstorm.p"
artsMS.downloadArtistURL(url, savename)

# %%
#bsdata = getHTML("/Users/tgadfort/Downloads/Featured bands - Metal Storm.html")
#artMT = artistMT()

# %%
#http://www.metalstorm.net/bands/index.php?b_sortby=&b_where=&b_what=&page=3

# %%
artMT = artistMT()
artsMT = artistsMT(discMT)
#artsMT.downloadSiteIndex(sleeptime=5)
artsMT.downloadArtistsFromIndex(sleeptime=5)
#retval = artMT.getData("metalstorm.p")
# Out:
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index1.p
# <__main__.artistMTURLInfo object at 0x1a266e0ba8>
# band.php?band_id=60
# Downloading Artist Data for ID [60]
# http://www.metalstorm.net/bands/discography.php?band_id=60
# /Volumes/Biggy/Discog/artists-metalstorm/60/60.p
# /Volumes/Biggy/Discog/artists-metalstorm/60/60.p exists.
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0da0>
# band.php?band_id=13
# Downloading Artist Data for ID [13]
# http://www.metalstorm.net/bands/discography.php?band_id=13
# /Volumes/Biggy/Discog/artists-metalstorm/13/13.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/13/13.p (force=False)
#   --> This file is 17.1kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0cf8>
# band.php?band_id=176
# Downloading Artist Data for ID [176]
# http://www.metalstorm.net/bands/discography.php?band_id=176
# /Volumes/Biggy/Discog/artists-metalstorm/76/176.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/76/176.p (force=False)
#   --> This file is 19.8kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0e80>
# band.php?band_id=163
# Downloading Artist Data for ID [163]
# http://www.metalstorm.net/bands/discography.php?band_id=163
# /Volumes/Biggy/Discog/artists-metalstorm/63/163.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/63/163.p (force=False)
#   --> This file is 19.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ef0>
# band.php?band_id=25
# Downloading Artist Data for ID [25]
# http://www.metalstorm.net/bands/discography.php?band_id=25
# /Volumes/Biggy/Discog/artists-metalstorm/25/25.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/25/25.p (force=False)
#   --> This file is 17.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0f28>
# band.php?band_id=183
# Downloading Artist Data for ID [183]
# http://www.metalstorm.net/bands/discography.php?band_id=183
# /Volumes/Biggy/Discog/artists-metalstorm/83/183.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/83/183.p (force=False)
#   --> This file is 17.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0dd8>
# band.php?band_id=83
# Downloading Artist Data for ID [83]
# http://www.metalstorm.net/bands/discography.php?band_id=83
# /Volumes/Biggy/Discog/artists-metalstorm/83/83.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/83/83.p (force=False)
#   --> This file is 16.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b70>
# band.php?band_id=52
# Downloading Artist Data for ID [52]
# http://www.metalstorm.net/bands/discography.php?band_id=52
# /Volumes/Biggy/Discog/artists-metalstorm/52/52.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/52/52.p (force=False)
#   --> This file is 18.3kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0d30>
# band.php?band_id=92
# Downloading Artist Data for ID [92]
# http://www.metalstorm.net/bands/discography.php?band_id=92
# /Volumes/Biggy/Discog/artists-metalstorm/92/92.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/92/92.p (force=False)
#   --> This file is 18.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ba8>
# band.php?band_id=78
# Downloading Artist Data for ID [78]
# http://www.metalstorm.net/bands/discography.php?band_id=78
# /Volumes/Biggy/Discog/artists-metalstorm/78/78.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/78/78.p (force=False)
#   --> This file is 18.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0cc0>
# band.php?band_id=1
# Downloading Artist Data for ID [1]
# http://www.metalstorm.net/bands/discography.php?band_id=1
# /Volumes/Biggy/Discog/artists-metalstorm/1/1.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/1/1.p (force=False)
#   --> This file is 17.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0dd8>
# band.php?band_id=72
# Downloading Artist Data for ID [72]
# http://www.metalstorm.net/bands/discography.php?band_id=72
# /Volumes/Biggy/Discog/artists-metalstorm/72/72.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/72/72.p (force=False)
#   --> This file is 16.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0f28>
# band.php?band_id=53
# Downloading Artist Data for ID [53]
# http://www.metalstorm.net/bands/discography.php?band_id=53
# /Volumes/Biggy/Discog/artists-metalstorm/53/53.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/53/53.p (force=False)
#   --> This file is 17.3kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ba8>
# band.php?band_id=80
# Downloading Artist Data for ID [80]
# http://www.metalstorm.net/bands/discography.php?band_id=80
# /Volumes/Biggy/Discog/artists-metalstorm/80/80.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/80/80.p (force=False)
#   --> This file is 17.7kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b70>
# band.php?band_id=58
# Downloading Artist Data for ID [58]
# http://www.metalstorm.net/bands/discography.php?band_id=58
# /Volumes/Biggy/Discog/artists-metalstorm/58/58.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/58/58.p (force=False)
#   --> This file is 16.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0e80>
# band.php?band_id=296
# Downloading Artist Data for ID [296]
# http://www.metalstorm.net/bands/discography.php?band_id=296
# /Volumes/Biggy/Discog/artists-metalstorm/96/296.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/96/296.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0cc0>
# band.php?band_id=61
# Downloading Artist Data for ID [61]
# http://www.metalstorm.net/bands/discography.php?band_id=61
# /Volumes/Biggy/Discog/artists-metalstorm/61/61.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/61/61.p (force=False)
#   --> This file is 17.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0d30>
# band.php?band_id=95
# Downloading Artist Data for ID [95]
# http://www.metalstorm.net/bands/discography.php?band_id=95
# /Volumes/Biggy/Discog/artists-metalstorm/95/95.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/95/95.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0eb8>
# band.php?band_id=50
# Downloading Artist Data for ID [50]
# http://www.metalstorm.net/bands/discography.php?band_id=50
# /Volumes/Biggy/Discog/artists-metalstorm/50/50.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/50/50.p (force=False)
#   --> This file is 18.7kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b70>
# band.php?band_id=137
# Downloading Artist Data for ID [137]
# http://www.metalstorm.net/bands/discography.php?band_id=137
# /Volumes/Biggy/Discog/artists-metalstorm/37/137.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/37/137.p (force=False)
#   --> This file is 17.8kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ba8>
# band.php?band_id=42
# Downloading Artist Data for ID [42]
# http://www.metalstorm.net/bands/discography.php?band_id=42
# /Volumes/Biggy/Discog/artists-metalstorm/42/42.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/42/42.p (force=False)
#   --> This file is 17.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0c18>
# band.php?band_id=142
# Downloading Artist Data for ID [142]
# http://www.metalstorm.net/bands/discography.php?band_id=142
# /Volumes/Biggy/Discog/artists-metalstorm/42/142.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/42/142.p (force=False)
#   --> This file is 19.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0e80>
# band.php?band_id=86
# Downloading Artist Data for ID [86]
# http://www.metalstorm.net/bands/discography.php?band_id=86
# /Volumes/Biggy/Discog/artists-metalstorm/86/86.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/86/86.p (force=False)
#   --> This file is 17.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0d30>
# band.php?band_id=384
# Downloading Artist Data for ID [384]
# http://www.metalstorm.net/bands/discography.php?band_id=384
# /Volumes/Biggy/Discog/artists-metalstorm/84/384.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/84/384.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0e48>
# band.php?band_id=425
# Downloading Artist Data for ID [425]
# http://www.metalstorm.net/bands/discography.php?band_id=425
# /Volumes/Biggy/Discog/artists-metalstorm/25/425.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/25/425.p (force=False)
#   --> This file is 15.3kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b70>
# band.php?band_id=26
# Downloading Artist Data for ID [26]
# http://www.metalstorm.net/bands/discography.php?band_id=26
# /Volumes/Biggy/Discog/artists-metalstorm/26/26.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/26/26.p (force=False)
#   --> This file is 16.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0d68>
# band.php?band_id=495
# Downloading Artist Data for ID [495]
# http://www.metalstorm.net/bands/discography.php?band_id=495
# /Volumes/Biggy/Discog/artists-metalstorm/95/495.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/95/495.p (force=False)
#   --> This file is 14.1kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ba8>
# band.php?band_id=181
# Downloading Artist Data for ID [181]
# http://www.metalstorm.net/bands/discography.php?band_id=181
# /Volumes/Biggy/Discog/artists-metalstorm/81/181.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/81/181.p (force=False)
#   --> This file is 16.3kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0e80>
# band.php?band_id=123
# Downloading Artist Data for ID [123]
# http://www.metalstorm.net/bands/discography.php?band_id=123
# /Volumes/Biggy/Discog/artists-metalstorm/23/123.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/23/123.p (force=False)
#   --> This file is 20.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ef0>
# band.php?band_id=136
# Downloading Artist Data for ID [136]
# http://www.metalstorm.net/bands/discography.php?band_id=136
# /Volumes/Biggy/Discog/artists-metalstorm/36/136.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/36/136.p (force=False)
#   --> This file is 16.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0eb8>
# band.php?band_id=124
# Downloading Artist Data for ID [124]
# http://www.metalstorm.net/bands/discography.php?band_id=124
# /Volumes/Biggy/Discog/artists-metalstorm/24/124.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/24/124.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0f28>
# band.php?band_id=475
# Downloading Artist Data for ID [475]
# http://www.metalstorm.net/bands/discography.php?band_id=475
# /Volumes/Biggy/Discog/artists-metalstorm/75/475.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/75/475.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ba8>
# band.php?band_id=208
# Downloading Artist Data for ID [208]
# http://www.metalstorm.net/bands/discography.php?band_id=208
# /Volumes/Biggy/Discog/artists-metalstorm/8/208.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/8/208.p (force=False)
#   --> This file is 16.3kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ef0>
# band.php?band_id=294
# Downloading Artist Data for ID [294]
# http://www.metalstorm.net/bands/discography.php?band_id=294
# /Volumes/Biggy/Discog/artists-metalstorm/94/294.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/94/294.p (force=False)
#   --> This file is 15.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0cf8>
# band.php?band_id=2
# Downloading Artist Data for ID [2]
# http://www.metalstorm.net/bands/discography.php?band_id=2
# /Volumes/Biggy/Discog/artists-metalstorm/2/2.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/2/2.p (force=False)
#   --> This file is 17.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0d30>
# band.php?band_id=28
# Downloading Artist Data for ID [28]
# http://www.metalstorm.net/bands/discography.php?band_id=28
# /Volumes/Biggy/Discog/artists-metalstorm/28/28.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/28/28.p (force=False)
#   --> This file is 16.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0f28>
# band.php?band_id=1064
# Downloading Artist Data for ID [1064]
# http://www.metalstorm.net/bands/discography.php?band_id=1064
# /Volumes/Biggy/Discog/artists-metalstorm/64/1064.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/64/1064.p (force=False)
#   --> This file is 15.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ef0>
# band.php?band_id=167
# Downloading Artist Data for ID [167]
# http://www.metalstorm.net/bands/discography.php?band_id=167
# /Volumes/Biggy/Discog/artists-metalstorm/67/167.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/67/167.p (force=False)
#   --> This file is 15.8kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0eb8>
# band.php?band_id=349
# Downloading Artist Data for ID [349]
# http://www.metalstorm.net/bands/discography.php?band_id=349
# /Volumes/Biggy/Discog/artists-metalstorm/49/349.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/49/349.p (force=False)
#   --> This file is 15.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0da0>
# band.php?band_id=15
# Downloading Artist Data for ID [15]
# http://www.metalstorm.net/bands/discography.php?band_id=15
# /Volumes/Biggy/Discog/artists-metalstorm/15/15.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/15/15.p (force=False)
#   --> This file is 15.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0e48>
# band.php?band_id=151
# Downloading Artist Data for ID [151]
# http://www.metalstorm.net/bands/discography.php?band_id=151
# /Volumes/Biggy/Discog/artists-metalstorm/51/151.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/51/151.p (force=False)
#   --> This file is 20.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0cf8>
# band.php?band_id=97
# Downloading Artist Data for ID [97]
# http://www.metalstorm.net/bands/discography.php?band_id=97
# /Volumes/Biggy/Discog/artists-metalstorm/97/97.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/97/97.p (force=False)
#   --> This file is 17.7kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ef0>
# band.php?band_id=172
# Downloading Artist Data for ID [172]
# http://www.metalstorm.net/bands/discography.php?band_id=172
# /Volumes/Biggy/Discog/artists-metalstorm/72/172.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/72/172.p (force=False)
#   --> This file is 17.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b70>
# band.php?band_id=94
# Downloading Artist Data for ID [94]
# http://www.metalstorm.net/bands/discography.php?band_id=94
# /Volumes/Biggy/Discog/artists-metalstorm/94/94.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/94/94.p (force=False)
#   --> This file is 15.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0dd8>
# band.php?band_id=166
# Downloading Artist Data for ID [166]
# http://www.metalstorm.net/bands/discography.php?band_id=166
# /Volumes/Biggy/Discog/artists-metalstorm/66/166.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/66/166.p (force=False)
#   --> This file is 17.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0da0>
# band.php?band_id=68
# Downloading Artist Data for ID [68]
# http://www.metalstorm.net/bands/discography.php?band_id=68
# /Volumes/Biggy/Discog/artists-metalstorm/68/68.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/68/68.p (force=False)
#   --> This file is 17.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0d68>
# band.php?band_id=130
# Downloading Artist Data for ID [130]
# http://www.metalstorm.net/bands/discography.php?band_id=130
# /Volumes/Biggy/Discog/artists-metalstorm/30/130.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/30/130.p (force=False)
#   --> This file is 15.7kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0c18>
# band.php?band_id=2346
# Downloading Artist Data for ID [2346]
# http://www.metalstorm.net/bands/discography.php?band_id=2346
# /Volumes/Biggy/Discog/artists-metalstorm/46/2346.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/46/2346.p (force=False)
#   --> This file is 12.8kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0e80>
# band.php?band_id=6
# Downloading Artist Data for ID [6]
# http://www.metalstorm.net/bands/discography.php?band_id=6
# /Volumes/Biggy/Discog/artists-metalstorm/6/6.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/6/6.p (force=False)
#   --> This file is 19.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b70>
# band.php?band_id=59
# Downloading Artist Data for ID [59]
# http://www.metalstorm.net/bands/discography.php?band_id=59
# /Volumes/Biggy/Discog/artists-metalstorm/59/59.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/59/59.p (force=False)
#   --> This file is 18.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index10.p
# <__main__.artistMTURLInfo object at 0x1a266e0a58>
# band.php?band_id=4557
# Downloading Artist Data for ID [4557]
# http://www.metalstorm.net/bands/discography.php?band_id=4557
# /Volumes/Biggy/Discog/artists-metalstorm/57/4557.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/57/4557.p (force=False)
#   --> This file is 14.1kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0e48>
# band.php?band_id=1618
# Downloading Artist Data for ID [1618]
# http://www.metalstorm.net/bands/discography.php?band_id=1618
# /Volumes/Biggy/Discog/artists-metalstorm/18/1618.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/18/1618.p (force=False)
#   --> This file is 13.3kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ef0>
# band.php?band_id=144
# Downloading Artist Data for ID [144]
# http://www.metalstorm.net/bands/discography.php?band_id=144
# /Volumes/Biggy/Discog/artists-metalstorm/44/144.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/44/144.p (force=False)
#   --> This file is 16.1kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0e48>
# band.php?band_id=510
# Downloading Artist Data for ID [510]
# http://www.metalstorm.net/bands/discography.php?band_id=510
# /Volumes/Biggy/Discog/artists-metalstorm/10/510.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/10/510.p (force=False)
#   --> This file is 14.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=3170
# Downloading Artist Data for ID [3170]
# http://www.metalstorm.net/bands/discography.php?band_id=3170
# /Volumes/Biggy/Discog/artists-metalstorm/70/3170.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/70/3170.p (force=False)
#   --> This file is 12.7kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a20>
# band.php?band_id=492
# Downloading Artist Data for ID [492]
# http://www.metalstorm.net/bands/discography.php?band_id=492
# /Volumes/Biggy/Discog/artists-metalstorm/92/492.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/92/492.p (force=False)
#   --> This file is 12.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ef0>
# band.php?band_id=2265
# Downloading Artist Data for ID [2265]
# http://www.metalstorm.net/bands/discography.php?band_id=2265
# /Volumes/Biggy/Discog/artists-metalstorm/65/2265.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/65/2265.p (force=False)
#   --> This file is 15.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b70>
# band.php?band_id=2333
# Downloading Artist Data for ID [2333]
# http://www.metalstorm.net/bands/discography.php?band_id=2333
# /Volumes/Biggy/Discog/artists-metalstorm/33/2333.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/33/2333.p (force=False)
#   --> This file is 14.3kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=34
# Downloading Artist Data for ID [34]
# http://www.metalstorm.net/bands/discography.php?band_id=34
# /Volumes/Biggy/Discog/artists-metalstorm/34/34.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/34/34.p (force=False)
#   --> This file is 14.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b38>
# band.php?band_id=3247
# Downloading Artist Data for ID [3247]
# http://www.metalstorm.net/bands/discography.php?band_id=3247
# /Volumes/Biggy/Discog/artists-metalstorm/47/3247.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/47/3247.p (force=False)
#   --> This file is 15.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ef0>
# band.php?band_id=4538
# Downloading Artist Data for ID [4538]
# http://www.metalstorm.net/bands/discography.php?band_id=4538
# /Volumes/Biggy/Discog/artists-metalstorm/38/4538.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/38/4538.p (force=False)
#   --> This file is 13.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b70>
# band.php?band_id=687
# Downloading Artist Data for ID [687]
# http://www.metalstorm.net/bands/discography.php?band_id=687
# /Volumes/Biggy/Discog/artists-metalstorm/87/687.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/87/687.p (force=False)
#   --> This file is 14.1kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0e48>
# band.php?band_id=1589
# Downloading Artist Data for ID [1589]
# http://www.metalstorm.net/bands/discography.php?band_id=1589
# /Volumes/Biggy/Discog/artists-metalstorm/89/1589.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/89/1589.p (force=False)
#   --> This file is 14.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a20>
# band.php?band_id=1223
# Downloading Artist Data for ID [1223]
# http://www.metalstorm.net/bands/discography.php?band_id=1223
# /Volumes/Biggy/Discog/artists-metalstorm/23/1223.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/23/1223.p (force=False)
#   --> This file is 14.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ef0>
# band.php?band_id=305
# Downloading Artist Data for ID [305]
# http://www.metalstorm.net/bands/discography.php?band_id=305
# /Volumes/Biggy/Discog/artists-metalstorm/5/305.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/5/305.p (force=False)
#   --> This file is 13.8kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b70>
# band.php?band_id=6020
# Downloading Artist Data for ID [6020]
# http://www.metalstorm.net/bands/discography.php?band_id=6020
# /Volumes/Biggy/Discog/artists-metalstorm/20/6020.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/20/6020.p (force=False)
#   --> This file is 13.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=4251
# Downloading Artist Data for ID [4251]
# http://www.metalstorm.net/bands/discography.php?band_id=4251
# /Volumes/Biggy/Discog/artists-metalstorm/51/4251.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/51/4251.p (force=False)
#   --> This file is 13.8kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a20>
# band.php?band_id=3569
# Downloading Artist Data for ID [3569]
# http://www.metalstorm.net/bands/discography.php?band_id=3569
# /Volumes/Biggy/Discog/artists-metalstorm/69/3569.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/69/3569.p (force=False)
#   --> This file is 14.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ef0>
# band.php?band_id=119
# Downloading Artist Data for ID [119]
# http://www.metalstorm.net/bands/discography.php?band_id=119
# /Volumes/Biggy/Discog/artists-metalstorm/19/119.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/19/119.p (force=False)
#   --> This file is 15.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b70>
# band.php?band_id=1607
# Downloading Artist Data for ID [1607]
# http://www.metalstorm.net/bands/discography.php?band_id=1607
# /Volumes/Biggy/Discog/artists-metalstorm/7/1607.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/7/1607.p (force=False)
#   --> This file is 15.7kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=4667
# Downloading Artist Data for ID [4667]
# http://www.metalstorm.net/bands/discography.php?band_id=4667
# /Volumes/Biggy/Discog/artists-metalstorm/67/4667.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/67/4667.p (force=False)
#   --> This file is 13.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a20>
# band.php?band_id=360
# Downloading Artist Data for ID [360]
# http://www.metalstorm.net/bands/discography.php?band_id=360
# /Volumes/Biggy/Discog/artists-metalstorm/60/360.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/60/360.p (force=False)
#   --> This file is 16.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ef0>
# band.php?band_id=3420
# Downloading Artist Data for ID [3420]
# http://www.metalstorm.net/bands/discography.php?band_id=3420
# /Volumes/Biggy/Discog/artists-metalstorm/20/3420.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/20/3420.p (force=False)
#   --> This file is 14.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b70>
# band.php?band_id=6861
# Downloading Artist Data for ID [6861]
# http://www.metalstorm.net/bands/discography.php?band_id=6861
# /Volumes/Biggy/Discog/artists-metalstorm/61/6861.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/61/6861.p (force=False)
#   --> This file is 12.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=7192
# Downloading Artist Data for ID [7192]
# http://www.metalstorm.net/bands/discography.php?band_id=7192
# /Volumes/Biggy/Discog/artists-metalstorm/92/7192.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/92/7192.p (force=False)
#   --> This file is 12.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a20>
# band.php?band_id=3402
# Downloading Artist Data for ID [3402]
# http://www.metalstorm.net/bands/discography.php?band_id=3402
# /Volumes/Biggy/Discog/artists-metalstorm/2/3402.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/2/3402.p (force=False)
#   --> This file is 16.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ef0>
# band.php?band_id=994
# Downloading Artist Data for ID [994]
# http://www.metalstorm.net/bands/discography.php?band_id=994
# /Volumes/Biggy/Discog/artists-metalstorm/94/994.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/94/994.p (force=False)
#   --> This file is 13.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e09e8>
# band.php?band_id=3040
# Downloading Artist Data for ID [3040]
# http://www.metalstorm.net/bands/discography.php?band_id=3040
# /Volumes/Biggy/Discog/artists-metalstorm/40/3040.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/40/3040.p (force=False)
#   --> This file is 16.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=194
# Downloading Artist Data for ID [194]
# http://www.metalstorm.net/bands/discography.php?band_id=194
# /Volumes/Biggy/Discog/artists-metalstorm/94/194.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/94/194.p (force=False)
#   --> This file is 13.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e09e8>
# band.php?band_id=7057
# Downloading Artist Data for ID [7057]
# http://www.metalstorm.net/bands/discography.php?band_id=7057
# /Volumes/Biggy/Discog/artists-metalstorm/57/7057.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/57/7057.p (force=False)
#   --> This file is 12.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ef0>
# band.php?band_id=2626
# Downloading Artist Data for ID [2626]
# http://www.metalstorm.net/bands/discography.php?band_id=2626
# /Volumes/Biggy/Discog/artists-metalstorm/26/2626.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/26/2626.p (force=False)
#   --> This file is 13.3kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b70>
# band.php?band_id=941
# Downloading Artist Data for ID [941]
# http://www.metalstorm.net/bands/discography.php?band_id=941
# /Volumes/Biggy/Discog/artists-metalstorm/41/941.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/41/941.p (force=False)
#   --> This file is 14.3kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=3
# Downloading Artist Data for ID [3]
# http://www.metalstorm.net/bands/discography.php?band_id=3
# /Volumes/Biggy/Discog/artists-metalstorm/3/3.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/3/3.p (force=False)
#   --> This file is 15.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ac8>
# band.php?band_id=9162
# Downloading Artist Data for ID [9162]
# http://www.metalstorm.net/bands/discography.php?band_id=9162
# /Volumes/Biggy/Discog/artists-metalstorm/62/9162.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/62/9162.p (force=False)
#   --> This file is 12.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0c18>
# band.php?band_id=2516
# Downloading Artist Data for ID [2516]
# http://www.metalstorm.net/bands/discography.php?band_id=2516
# /Volumes/Biggy/Discog/artists-metalstorm/16/2516.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/16/2516.p (force=False)
#   --> This file is 15.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e09e8>
# band.php?band_id=196
# Downloading Artist Data for ID [196]
# http://www.metalstorm.net/bands/discography.php?band_id=196
# /Volumes/Biggy/Discog/artists-metalstorm/96/196.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/96/196.p (force=False)
#   --> This file is 14.1kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=965
# Downloading Artist Data for ID [965]
# http://www.metalstorm.net/bands/discography.php?band_id=965
# /Volumes/Biggy/Discog/artists-metalstorm/65/965.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/65/965.p (force=False)
#   --> This file is 14.3kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a20>
# band.php?band_id=503
# Downloading Artist Data for ID [503]
# http://www.metalstorm.net/bands/discography.php?band_id=503
# /Volumes/Biggy/Discog/artists-metalstorm/3/503.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/3/503.p (force=False)
#   --> This file is 13.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0c18>
# band.php?band_id=2821
# Downloading Artist Data for ID [2821]
# http://www.metalstorm.net/bands/discography.php?band_id=2821
# /Volumes/Biggy/Discog/artists-metalstorm/21/2821.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/21/2821.p (force=False)
#   --> This file is 14.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b70>
# band.php?band_id=178
# Downloading Artist Data for ID [178]
# http://www.metalstorm.net/bands/discography.php?band_id=178
# /Volumes/Biggy/Discog/artists-metalstorm/78/178.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/78/178.p (force=False)
#   --> This file is 16.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=480
# Downloading Artist Data for ID [480]
# http://www.metalstorm.net/bands/discography.php?band_id=480
# /Volumes/Biggy/Discog/artists-metalstorm/80/480.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/80/480.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b70>
# band.php?band_id=1079
# Downloading Artist Data for ID [1079]
# http://www.metalstorm.net/bands/discography.php?band_id=1079
# /Volumes/Biggy/Discog/artists-metalstorm/79/1079.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/79/1079.p (force=False)
#   --> This file is 13.8kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0c18>
# band.php?band_id=511
# Downloading Artist Data for ID [511]
# http://www.metalstorm.net/bands/discography.php?band_id=511
# /Volumes/Biggy/Discog/artists-metalstorm/11/511.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/11/511.p (force=False)
#   --> This file is 14.3kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e09e8>
# band.php?band_id=180
# Downloading Artist Data for ID [180]
# http://www.metalstorm.net/bands/discography.php?band_id=180
# /Volumes/Biggy/Discog/artists-metalstorm/80/180.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/80/180.p (force=False)
#   --> This file is 16.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=3156
# Downloading Artist Data for ID [3156]
# http://www.metalstorm.net/bands/discography.php?band_id=3156
# /Volumes/Biggy/Discog/artists-metalstorm/56/3156.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/56/3156.p (force=False)
#   --> This file is 14.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a20>
# band.php?band_id=2772
# Downloading Artist Data for ID [2772]
# http://www.metalstorm.net/bands/discography.php?band_id=2772
# /Volumes/Biggy/Discog/artists-metalstorm/72/2772.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/72/2772.p (force=False)
#   --> This file is 13.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0b70>
# band.php?band_id=242
# Downloading Artist Data for ID [242]
# http://www.metalstorm.net/bands/discography.php?band_id=242
# /Volumes/Biggy/Discog/artists-metalstorm/42/242.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/42/242.p (force=False)
#   --> This file is 15.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e09e8>
# band.php?band_id=221
# Downloading Artist Data for ID [221]
# http://www.metalstorm.net/bands/discography.php?band_id=221
# /Volumes/Biggy/Discog/artists-metalstorm/21/221.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/21/221.p (force=False)
#   --> This file is 14.1kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=432
# Downloading Artist Data for ID [432]
# http://www.metalstorm.net/bands/discography.php?band_id=432
# /Volumes/Biggy/Discog/artists-metalstorm/32/432.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/32/432.p (force=False)
#   --> This file is 16.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a20>
# band.php?band_id=2701
# Downloading Artist Data for ID [2701]
# http://www.metalstorm.net/bands/discography.php?band_id=2701
# /Volumes/Biggy/Discog/artists-metalstorm/1/2701.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/1/2701.p (force=False)
#   --> This file is 13.8kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index100.p
# <__main__.artistMTURLInfo object at 0x1a25f115f8>
# band.php?band_id=10169
# Downloading Artist Data for ID [10169]
# http://www.metalstorm.net/bands/discography.php?band_id=10169
# /Volumes/Biggy/Discog/artists-metalstorm/69/10169.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/69/10169.p (force=False)
#   --> This file is 12.1kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0c18>
# band.php?band_id=10249
# Downloading Artist Data for ID [10249]
# http://www.metalstorm.net/bands/discography.php?band_id=10249
# /Volumes/Biggy/Discog/artists-metalstorm/49/10249.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/49/10249.p (force=False)
#   --> This file is 12.1kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a25f116a0>
# band.php?band_id=3389
# Downloading Artist Data for ID [3389]
# http://www.metalstorm.net/bands/discography.php?band_id=3389
# /Volumes/Biggy/Discog/artists-metalstorm/89/3389.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/89/3389.p (force=False)
#   --> This file is 12.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ac8>
# band.php?band_id=10611
# Downloading Artist Data for ID [10611]
# http://www.metalstorm.net/bands/discography.php?band_id=10611
# /Volumes/Biggy/Discog/artists-metalstorm/11/10611.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/11/10611.p (force=False)
#   --> This file is 12.1kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a25f115f8>
# band.php?band_id=7555
# Downloading Artist Data for ID [7555]
# http://www.metalstorm.net/bands/discography.php?band_id=7555
# /Volumes/Biggy/Discog/artists-metalstorm/55/7555.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/55/7555.p (force=False)
#   --> This file is 12.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0c18>
# band.php?band_id=9243
# Downloading Artist Data for ID [9243]
# http://www.metalstorm.net/bands/discography.php?band_id=9243
# /Volumes/Biggy/Discog/artists-metalstorm/43/9243.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/43/9243.p (force=False)
#   --> This file is 12.3kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a25f116a0>
# band.php?band_id=3745
# Downloading Artist Data for ID [3745]
# http://www.metalstorm.net/bands/discography.php?band_id=3745
# /Volumes/Biggy/Discog/artists-metalstorm/45/3745.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/45/3745.p (force=False)
#   --> This file is 12.8kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ac8>
# band.php?band_id=10417
# Downloading Artist Data for ID [10417]
# http://www.metalstorm.net/bands/discography.php?band_id=10417
# /Volumes/Biggy/Discog/artists-metalstorm/17/10417.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/17/10417.p (force=False)
#   --> This file is 12.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a25f115f8>
# band.php?band_id=5417
# Downloading Artist Data for ID [5417]
# http://www.metalstorm.net/bands/discography.php?band_id=5417
# /Volumes/Biggy/Discog/artists-metalstorm/17/5417.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/17/5417.p (force=False)
#   --> This file is 12.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0ac8>
# band.php?band_id=9870
# Downloading Artist Data for ID [9870]
# http://www.metalstorm.net/bands/discography.php?band_id=9870
# /Volumes/Biggy/Discog/artists-metalstorm/70/9870.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/70/9870.p (force=False)
#   --> This file is 12.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a20>
# band.php?band_id=9374
# Downloading Artist Data for ID [9374]
# http://www.metalstorm.net/bands/discography.php?band_id=9374
# /Volumes/Biggy/Discog/artists-metalstorm/74/9374.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/74/9374.p (force=False)
#   --> This file is 12.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0c18>
# band.php?band_id=10285
# Downloading Artist Data for ID [10285]
# http://www.metalstorm.net/bands/discography.php?band_id=10285
# /Volumes/Biggy/Discog/artists-metalstorm/85/10285.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/85/10285.p (force=False)
#   --> This file is 12.7kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a25f115f8>
# band.php?band_id=1323
# Downloading Artist Data for ID [1323]
# http://www.metalstorm.net/bands/discography.php?band_id=1323
# /Volumes/Biggy/Discog/artists-metalstorm/23/1323.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/23/1323.p (force=False)
#   --> This file is 13.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0c18>
# band.php?band_id=8719
# Downloading Artist Data for ID [8719]
# http://www.metalstorm.net/bands/discography.php?band_id=8719
# /Volumes/Biggy/Discog/artists-metalstorm/19/8719.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/19/8719.p (force=False)
#   --> This file is 12.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a25f116a0>
# band.php?band_id=8327
# Downloading Artist Data for ID [8327]
# http://www.metalstorm.net/bands/discography.php?band_id=8327
# /Volumes/Biggy/Discog/artists-metalstorm/27/8327.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/27/8327.p (force=False)
#   --> This file is 12.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0c18>
# band.php?band_id=11333
# Downloading Artist Data for ID [11333]
# http://www.metalstorm.net/bands/discography.php?band_id=11333
# /Volumes/Biggy/Discog/artists-metalstorm/33/11333.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/33/11333.p (force=False)
#   --> This file is 12.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=7501
# Downloading Artist Data for ID [7501]
# http://www.metalstorm.net/bands/discography.php?band_id=7501
# /Volumes/Biggy/Discog/artists-metalstorm/1/7501.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/1/7501.p (force=False)
#   --> This file is 12.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0c18>
# band.php?band_id=6467
# Downloading Artist Data for ID [6467]
# http://www.metalstorm.net/bands/discography.php?band_id=6467
# /Volumes/Biggy/Discog/artists-metalstorm/67/6467.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/67/6467.p (force=False)
#   --> This file is 12.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=5508
# Downloading Artist Data for ID [5508]
# http://www.metalstorm.net/bands/discography.php?band_id=5508
# /Volumes/Biggy/Discog/artists-metalstorm/8/5508.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/8/5508.p (force=False)
#   --> This file is 12.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a20>
# band.php?band_id=9837
# Downloading Artist Data for ID [9837]
# http://www.metalstorm.net/bands/discography.php?band_id=9837
# /Volumes/Biggy/Discog/artists-metalstorm/37/9837.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/37/9837.p (force=False)
#   --> This file is 12.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a25f115f8>
# band.php?band_id=5671
# Downloading Artist Data for ID [5671]
# http://www.metalstorm.net/bands/discography.php?band_id=5671
# /Volumes/Biggy/Discog/artists-metalstorm/71/5671.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/71/5671.p (force=False)
#   --> This file is 12.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=6339
# Downloading Artist Data for ID [6339]
# http://www.metalstorm.net/bands/discography.php?band_id=6339
# /Volumes/Biggy/Discog/artists-metalstorm/39/6339.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/39/6339.p (force=False)
#   --> This file is 12.7kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a25f116a0>
# band.php?band_id=7916
# Downloading Artist Data for ID [7916]
# http://www.metalstorm.net/bands/discography.php?band_id=7916
# /Volumes/Biggy/Discog/artists-metalstorm/16/7916.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/16/7916.p (force=False)
#   --> This file is 12.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=8950
# Downloading Artist Data for ID [8950]
# http://www.metalstorm.net/bands/discography.php?band_id=8950
# /Volumes/Biggy/Discog/artists-metalstorm/50/8950.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/50/8950.p (force=False)
#   --> This file is 11.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a25f115f8>
# band.php?band_id=8218
# Downloading Artist Data for ID [8218]
# http://www.metalstorm.net/bands/discography.php?band_id=8218
# /Volumes/Biggy/Discog/artists-metalstorm/18/8218.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/18/8218.p (force=False)
#   --> This file is 13.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a90>
# band.php?band_id=9055
# Downloading Artist Data for ID [9055]
# http://www.metalstorm.net/bands/discography.php?band_id=9055
# /Volumes/Biggy/Discog/artists-metalstorm/55/9055.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/55/9055.p (force=False)
#   --> This file is 12.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0a20>
# band.php?band_id=10407
# Downloading Artist Data for ID [10407]
# http://www.metalstorm.net/bands/discography.php?band_id=10407
# /Volumes/Biggy/Discog/artists-metalstorm/7/10407.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/7/10407.p (force=False)
#   --> This file is 12.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a266e0c18>
# band.php?band_id=5756
# Downloading Artist Data for ID [5756]
# ...
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a25a70898>
# band.php?band_id=11347
# Downloading Artist Data for ID [11347]
# http://www.metalstorm.net/bands/discography.php?band_id=11347
# /Volumes/Biggy/Discog/artists-metalstorm/47/11347.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/47/11347.p (force=False)
#   --> This file is 12.7kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a25a70828>
# band.php?band_id=10740
# Downloading Artist Data for ID [10740]
# http://www.metalstorm.net/bands/discography.php?band_id=10740
# /Volumes/Biggy/Discog/artists-metalstorm/40/10740.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/40/10740.p (force=False)
#   --> This file is 12.8kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a25a70898>
# band.php?band_id=9695
# Downloading Artist Data for ID [9695]
# http://www.metalstorm.net/bands/discography.php?band_id=9695
# /Volumes/Biggy/Discog/artists-metalstorm/95/9695.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/95/9695.p (force=False)
#   --> This file is 12.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a25a708d0>
# band.php?band_id=10312
# Downloading Artist Data for ID [10312]
# http://www.metalstorm.net/bands/discography.php?band_id=10312
# /Volumes/Biggy/Discog/artists-metalstorm/12/10312.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/12/10312.p (force=False)
#   --> This file is 12.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a25a70908>
# band.php?band_id=8883
# Downloading Artist Data for ID [8883]
# http://www.metalstorm.net/bands/discography.php?band_id=8883
# /Volumes/Biggy/Discog/artists-metalstorm/83/8883.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/83/8883.p (force=False)
#   --> This file is 12.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a25a708d0>
# band.php?band_id=9131
# Downloading Artist Data for ID [9131]
# http://www.metalstorm.net/bands/discography.php?band_id=9131
# /Volumes/Biggy/Discog/artists-metalstorm/31/9131.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/31/9131.p (force=False)
#   --> This file is 12.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# ====> /Volumes/Biggy/Discog/artists-metalstorm/index/index113.p
# <__main__.artistMTURLInfo object at 0x1a26214630>
# band.php?band_id=9379
# Downloading Artist Data for ID [9379]
# http://www.metalstorm.net/bands/discography.php?band_id=9379
# /Volumes/Biggy/Discog/artists-metalstorm/79/9379.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/79/9379.p (force=False)
#   --> This file is 12.8kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214588>
# band.php?band_id=8917
# Downloading Artist Data for ID [8917]
# http://www.metalstorm.net/bands/discography.php?band_id=8917
# /Volumes/Biggy/Discog/artists-metalstorm/17/8917.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/17/8917.p (force=False)
#   --> This file is 12.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a262146d8>
# band.php?band_id=9974
# Downloading Artist Data for ID [9974]
# http://www.metalstorm.net/bands/discography.php?band_id=9974
# /Volumes/Biggy/Discog/artists-metalstorm/74/9974.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/74/9974.p (force=False)
#   --> This file is 12.3kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214550>
# band.php?band_id=11319
# Downloading Artist Data for ID [11319]
# http://www.metalstorm.net/bands/discography.php?band_id=11319
# /Volumes/Biggy/Discog/artists-metalstorm/19/11319.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/19/11319.p (force=False)
#   --> This file is 11.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214630>
# band.php?band_id=9536
# Downloading Artist Data for ID [9536]
# http://www.metalstorm.net/bands/discography.php?band_id=9536
# /Volumes/Biggy/Discog/artists-metalstorm/36/9536.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/36/9536.p (force=False)
#   --> This file is 12.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214588>
# band.php?band_id=5278
# Downloading Artist Data for ID [5278]
# http://www.metalstorm.net/bands/discography.php?band_id=5278
# /Volumes/Biggy/Discog/artists-metalstorm/78/5278.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/78/5278.p (force=False)
#   --> This file is 12.8kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a262146d8>
# band.php?band_id=9167
# Downloading Artist Data for ID [9167]
# http://www.metalstorm.net/bands/discography.php?band_id=9167
# /Volumes/Biggy/Discog/artists-metalstorm/67/9167.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/67/9167.p (force=False)
#   --> This file is 12.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214550>
# band.php?band_id=9021
# Downloading Artist Data for ID [9021]
# http://www.metalstorm.net/bands/discography.php?band_id=9021
# /Volumes/Biggy/Discog/artists-metalstorm/21/9021.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/21/9021.p (force=False)
#   --> This file is 12.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214630>
# band.php?band_id=740
# Downloading Artist Data for ID [740]
# http://www.metalstorm.net/bands/discography.php?band_id=740
# /Volumes/Biggy/Discog/artists-metalstorm/40/740.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/40/740.p (force=False)
#   --> This file is 12.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214588>
# band.php?band_id=7973
# Downloading Artist Data for ID [7973]
# http://www.metalstorm.net/bands/discography.php?band_id=7973
# /Volumes/Biggy/Discog/artists-metalstorm/73/7973.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/73/7973.p (force=False)
#   --> This file is 12.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a262146d8>
# band.php?band_id=10563
# Downloading Artist Data for ID [10563]
# http://www.metalstorm.net/bands/discography.php?band_id=10563
# /Volumes/Biggy/Discog/artists-metalstorm/63/10563.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/63/10563.p (force=False)
#   --> This file is 12.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214550>
# band.php?band_id=8021
# Downloading Artist Data for ID [8021]
# http://www.metalstorm.net/bands/discography.php?band_id=8021
# /Volumes/Biggy/Discog/artists-metalstorm/21/8021.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/21/8021.p (force=False)
#   --> This file is 12.7kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a262145f8>
# band.php?band_id=11492
# Downloading Artist Data for ID [11492]
# http://www.metalstorm.net/bands/discography.php?band_id=11492
# /Volumes/Biggy/Discog/artists-metalstorm/92/11492.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/92/11492.p (force=False)
#   --> This file is 11.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214550>
# band.php?band_id=1963
# Downloading Artist Data for ID [1963]
# http://www.metalstorm.net/bands/discography.php?band_id=1963
# /Volumes/Biggy/Discog/artists-metalstorm/63/1963.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/63/1963.p (force=False)
#   --> This file is 12.4kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214630>
# band.php?band_id=8478
# Downloading Artist Data for ID [8478]
# http://www.metalstorm.net/bands/discography.php?band_id=8478
# /Volumes/Biggy/Discog/artists-metalstorm/78/8478.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/78/8478.p (force=False)
#   --> This file is 12.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214550>
# band.php?band_id=882
# Downloading Artist Data for ID [882]
# http://www.metalstorm.net/bands/discography.php?band_id=882
# /Volumes/Biggy/Discog/artists-metalstorm/82/882.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/82/882.p (force=False)
#   --> This file is 12.9kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214630>
# band.php?band_id=3270
# Downloading Artist Data for ID [3270]
# http://www.metalstorm.net/bands/discography.php?band_id=3270
# /Volumes/Biggy/Discog/artists-metalstorm/70/3270.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/70/3270.p (force=False)
#   --> This file is 12.6kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a262145f8>
# band.php?band_id=11167
# Downloading Artist Data for ID [11167]
# http://www.metalstorm.net/bands/discography.php?band_id=11167
# /Volumes/Biggy/Discog/artists-metalstorm/67/11167.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/67/11167.p (force=False)
#   --> This file is 12.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214588>
# band.php?band_id=8960
# Downloading Artist Data for ID [8960]
# http://www.metalstorm.net/bands/discography.php?band_id=8960
# /Volumes/Biggy/Discog/artists-metalstorm/60/8960.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/60/8960.p (force=False)
#   --> This file is 12.7kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214630>
# band.php?band_id=9625
# Downloading Artist Data for ID [9625]
# http://www.metalstorm.net/bands/discography.php?band_id=9625
# /Volumes/Biggy/Discog/artists-metalstorm/25/9625.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/25/9625.p (force=False)
#   --> This file is 12.1kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a262145f8>
# band.php?band_id=11020
# Downloading Artist Data for ID [11020]
# http://www.metalstorm.net/bands/discography.php?band_id=11020
# /Volumes/Biggy/Discog/artists-metalstorm/20/11020.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/20/11020.p (force=False)
#   --> This file is 12.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a262146d8>
# band.php?band_id=4182
# Downloading Artist Data for ID [4182]
# http://www.metalstorm.net/bands/discography.php?band_id=4182
# /Volumes/Biggy/Discog/artists-metalstorm/82/4182.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/82/4182.p (force=False)
#   --> This file is 11.8kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214588>
# band.php?band_id=5327
# Downloading Artist Data for ID [5327]
# http://www.metalstorm.net/bands/discography.php?band_id=5327
# /Volumes/Biggy/Discog/artists-metalstorm/27/5327.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/27/5327.p (force=False)
#   --> This file is 12.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214550>
# band.php?band_id=8818
# Downloading Artist Data for ID [8818]
# http://www.metalstorm.net/bands/discography.php?band_id=8818
# /Volumes/Biggy/Discog/artists-metalstorm/18/8818.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/18/8818.p (force=False)
#   --> This file is 12.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a262145f8>
# band.php?band_id=3104
# Downloading Artist Data for ID [3104]
# http://www.metalstorm.net/bands/discography.php?band_id=3104
# /Volumes/Biggy/Discog/artists-metalstorm/4/3104.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/4/3104.p (force=False)
#   --> This file is 12.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a262146d8>
# band.php?band_id=8416
# Downloading Artist Data for ID [8416]
# http://www.metalstorm.net/bands/discography.php?band_id=8416
# /Volumes/Biggy/Discog/artists-metalstorm/16/8416.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/16/8416.p (force=False)
#   --> This file is 12.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214588>
# band.php?band_id=3649
# Downloading Artist Data for ID [3649]
# http://www.metalstorm.net/bands/discography.php?band_id=3649
# /Volumes/Biggy/Discog/artists-metalstorm/49/3649.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/49/3649.p (force=False)
#   --> This file is 14.7kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214630>
# band.php?band_id=9782
# Downloading Artist Data for ID [9782]
# http://www.metalstorm.net/bands/discography.php?band_id=9782
# /Volumes/Biggy/Discog/artists-metalstorm/82/9782.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/82/9782.p (force=False)
#   --> This file is 12.0kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214588>
# band.php?band_id=7551
# Downloading Artist Data for ID [7551]
# http://www.metalstorm.net/bands/discography.php?band_id=7551
# /Volumes/Biggy/Discog/artists-metalstorm/51/7551.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/51/7551.p (force=False)
#   --> This file is 12.1kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214630>
# band.php?band_id=3257
# Downloading Artist Data for ID [3257]
# http://www.metalstorm.net/bands/discography.php?band_id=3257
# /Volumes/Biggy/Discog/artists-metalstorm/57/3257.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/57/3257.p (force=False)
#   --> This file is 12.3kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a262145f8>
# band.php?band_id=11595
# Downloading Artist Data for ID [11595]
# http://www.metalstorm.net/bands/discography.php?band_id=11595
# /Volumes/Biggy/Discog/artists-metalstorm/95/11595.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/95/11595.p (force=False)
#   --> This file is 12.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214588>
# band.php?band_id=10013
# Downloading Artist Data for ID [10013]
# http://www.metalstorm.net/bands/discography.php?band_id=10013
# /Volumes/Biggy/Discog/artists-metalstorm/13/10013.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/13/10013.p (force=False)
#   --> This file is 12.2kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214630>
# band.php?band_id=11251
# Downloading Artist Data for ID [11251]
# http://www.metalstorm.net/bands/discography.php?band_id=11251
# /Volumes/Biggy/Discog/artists-metalstorm/51/11251.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/51/11251.p (force=False)
#   --> This file is 11.8kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214748>
# band.php?band_id=10724
# Downloading Artist Data for ID [10724]
# http://www.metalstorm.net/bands/discography.php?band_id=10724
# /Volumes/Biggy/Discog/artists-metalstorm/24/10724.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/24/10724.p (force=False)
#   --> This file is 11.8kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214588>
# band.php?band_id=11298
# Downloading Artist Data for ID [11298]
# http://www.metalstorm.net/bands/discography.php?band_id=11298
# /Volumes/Biggy/Discog/artists-metalstorm/98/11298.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/98/11298.p (force=False)
#   --> This file is 12.5kB.
# Done. Sleeping for 5 seconds
# Done with download artist URL
# <__main__.artistMTURLInfo object at 0x1a26214630>
# band.php?band_id=2032
# Downloading Artist Data for ID [2032]
# http://www.metalstorm.net/bands/discography.php?band_id=2032
# /Volumes/Biggy/Discog/artists-metalstorm/32/2032.p

# %%
# Out:
# <__main__.artistMTURLInfo object at 0x1a25e164e0>
# band.php?band_id=60
# 60 http://www.metalstorm.net/bands/discography.php?band_id=60
# Downloading Artist Data for ID [60]
# http://www.metalstorm.net/bands/discography.php?band_id=60
# /Volumes/Biggy/Discog/artists-metalstorm/60/60.p
# Saving /Volumes/Biggy/Discog/artists-metalstorm/60/60.p (force=False)
#   --> This file is 18.0kB.
# Done. Sleeping for 2 seconds
# Done with download artist URL
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-70-e9ca4e318a83> in <module>
#      19             print(artistID,url)
#      20             artsMT.downloadArtistFromID(artistID)
# ---> 21             1/0
#      22
#      23         else:
#
# ZeroDivisionError: division by zero

# %%
print(retval.artist.get())
print(retval.url.get())
print(retval.ID.get())
print(retval.mediaCounts.get())
for mediaType,mediaData in retval.media.media.items():
    print(mediaType)
    for media in mediaData:
        print("\t",media.get())

# %%
retval = artCL.getData("/Volumes/Biggy/Discog/artists-cdandlp/65/63161947632565.p")

# %%
url="https://listen.tidal.com/artist/3565368"
savename="tidal.p"
artsMS.downloadArtistURL(url, savename)

# %%
bsdata = getFile("tidal.p")

# %%
bsdata

# %%
retval.artist.get()

# %%
dutils.getArtistID("https://www.cdandlp.com/en/a-flock-of-seagulls/artist/")

# %%
retval.url.get()

# %%
retval.ID.get()

# %%
retval.pages.get()

# %%
for k,v in retval.media.media.items():
    for v2 in v:
        print(v2.get())
